# %% [markdown]
# # Conscise Notes

# %% [markdown]
# I want notes to be useful, so I'll pull out what I need

# %% [markdown]
# $y''=f(t,y,y')$ missing a value
#
# No y: Replace down to $y'$ <br>
# $y''=f(t,y') \rightarrow (y')'=f(t,(y)')$ <br>
# This lets us treat it like a first order, so just solve naturally and then integrate one extra time
#
# No t: Use some magic formulas from the book. <br>
# Rewrite $y' = v, y'' = v'$ so $y''=f(y,y') \rightarrow v' = f(y,v)$ <br>
# Use sorcery $\dot w = \frac{v'}{v}$ find $w(y(t))=v(t)$. Don't forget ivp's!
#
# ROM: Finding a second solution given a first. <br>
# In this case we use a magic formula that you need to memorize
#
# ![image.png](attachment:image.png)
#
# Of course, $A_1$ is the factor y' is multiplied by ($a_0$ not pictured)

# %% [markdown]
# Laplace
#
# on/off switch
#
# ![image.png](attachment:image.png)
#
# For inversing, separate step function and put in (t-n) for (t) once you're done

# %% [markdown]
# Linalg
#
# $x' = Ax$
#
# Normal stuff: $c\vec \nu e^\lambda$
#
# What if $\lambda$ and $\vec \nu$ are repeated? We need $w$ to create the diag matrix.
#
# $$ (A -\lambda I)\vec w = \vec \nu $$
#
# Normalize: all about $a+bi$. $\cos/\sin$ for $b$, $e^a$ for $a$. then use $\frac{1}{2}$ or $\frac{1}{2i}$. Swap functions and sign for second function
