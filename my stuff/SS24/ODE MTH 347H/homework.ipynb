# %% [markdown]
# # Homework
# I didn't want to go back to my car to get paper

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# -yt+yc=1 \\
# c = \dfrac{1+yt}{y}
# $$

# %% [markdown]
# $y(0)=1$
# c = 1/1
#
# $y(0)=2$
# c = 1/2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $N = y^4+2y^3+4y^2-y-5$
# $M = 5t^2$
#
# $\partial_t N = 0$
#
# $\partial_y M = 0$
#
# $$1/5y^5+2/4y^4+4/3y^3-1/2y^2-5y$$
#
# $$5/3t^3$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# \dfrac{y'}{4y^{1/5}}=1 \\
# \frac{1}{4}\int y^{-1/5}dy=t+c \\
# \frac{5}{16}y^{4/5}=t+c \\
# y = \sqrt[4]{\left( \frac{16}{5}t+c \right)^5}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# y''=\frac{3}{t}y'+\frac{3}{t^2} \\
# a(t)=\frac{3}{t}, \ b(t)= \frac{3}{t^2}\\
# y'=a(t)y+b \\
# y'-a(t)y=b \\
# e^{A(t)}=e^{3ln(t)}
# \mu(t)=e^{-A(t)} \\
# y = ce^{A(t)}+e^{A(t)}\int\mu(t) b(t)dt \\
# \int {3}{t}dt=\ln(t^3) \rightarrow -\ln(t^3)=\ln(t^{-3})  \\
# y'=ct^3+t^3\int t^{-3} 3t^{-2}dt=ct^3+3t^3\int t^{-5} dt\\
# =ct^3+t^3(-\frac{t^{-6}}{6})=ct^3-\frac{1}{6t^3}
# $$

# %% [markdown]
# $$
# (\mu y')' = \mu y'' - a(t) \mu y'
#
# $$

# %% [markdown]
# $$
# \mu y'=\int \mu b(t) dt = \int \frac{1}{t^3} \frac{3}{t^2} dt = 3\int \frac{dt}{t^5} \\
# =-\frac{3}{4t^4}+c \\
# y' = ct^3-\frac{3t^3}{4t^4}=ct^3-\frac{3}{4t} \\
# \frac{3}{2} = c-\frac{3}{4} \\
# c = \frac{9}{4}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# -4 = c_1 + c_2 + 1/8 \\
# -2 = c_1 + 3c_2 - 1/8
# $$
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# $$
# y_p(t) = kte^{2t} \\
# y_p'(t) = k(2t+1)e^{2t} \\
# y_p''(t) = k4e^{2t}(t+1) \\
# 2e^{2t}=k4e^{2t}(t+1)-7k(2t+1)e^{2t}+10kte^{2t} \\
# 2=k4(t+1)-7k(2t+1)+10kt \\
# k = -2/3
# $$

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png) ![image-4.png](attachment:image-4.png) $f(t) = $![image-5.png](attachment:image-5.png)

# %% [markdown]
# $$
# u_1 = -\int \frac{-e^t}{e^{2t}t^2} te^t = \int \frac{e^{2t}}{te^{2t}} = \ln(t) \\
# u_2 = -\int \frac{1}{t^2} =\frac{1}{t}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)
#
# $$
# y_1 = \sin(t) \\
# y_2 = \cos(t) \\
# f = - \frac{1}{\cos(t)} \\
# W = -1 \\
# \frac{f}{W}=\frac{1}{\cos(t)}\\
#
# -\int \cos(t)/\cos(t)dt = -t \\
# \int \tan(t)dt = -\ln(\cos(t))
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# w = e^{6t} \\
# \frac{f}{w} = \frac{3}{t^3e^{3t}} \\
# -\int \frac{3}{t^2} = \frac{3}{t} = u_1 \\
# \int \frac{3}{t^3} = -\frac{3}{2t^2} =u_2 \\
#
# y_p = \frac{3}{t}e^{3t} -\frac{3}{2t}e^{3t}
# $$
