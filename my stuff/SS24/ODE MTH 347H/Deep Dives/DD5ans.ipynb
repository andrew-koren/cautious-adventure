# %% [markdown]
# # Deep Dive #5
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Properties of $\sigma $ and $\gamma$:
# - Homogenous
# - Constant coefficients
# - Linear
# - Defined for all initial data ($f(x)=1$ and $f(x)=0$ are continuous)
# - $W_{\gamma\sigma}(0)=1$

# %% [markdown]
# <div style="background-color:PaleGreen;color:black;padding:2%;">
#
# By Theorem 2.1.12, $\gamma$ and $\sigma$ aren't fundamental solutions of the of a SOLDE $L(y) =0 $, so they are linearly independent

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If $\gamma(t) = \gamma(-t)$, then both are linearly dependent
# $\rightarrow$ Show $W_{\gamma\hat \gamma}=0 $

# %% [markdown]
# $\gamma:$ Choose IVP s.t. $\hat \gamma(x)=\gamma(-x)$
#
# $$
# \gamma(0) = 1 \implies \hat \gamma(-0)=1  \\
# W_{\gamma\hat \gamma}(0)=1*\hat\gamma'(-0)-0*\hat\gamma(0) \implies \hat\gamma'(-0)=0 \\
# -\gamma(0)=\gamma''(0)=-1 \implies \hat \gamma''(-0) = -1
# $$
#
# Since the initial values  $\hat \gamma(0) = \gamma(-0)$ are the same as the initial values $\gamma(0)$, they are identical unique solutions, $\hat \gamma(x) = \gamma(-x)=\gamma(x)$

# %% [markdown]
# $\sigma: $ Choose IVP s.t. $\hat\sigma(x) = -\sigma(x)$
#
# $$
# \sigma(0)=0 \implies \hat\sigma(-0)=-0 \\
# %\hat \sigma(-0) = -1? \\
# \sigma(0)=-\sigma''(0) = 0 \implies \hat \sigma(-0) = -0 \\
# L(\sigma) + L(\hat \sigma) = 0 \implies \sigma''(0) + \sigma(0) + \hat \sigma''(0) + \hat \sigma'(0) + \hat \sigma(0)  = 0 \\
# 0+0
# $$
