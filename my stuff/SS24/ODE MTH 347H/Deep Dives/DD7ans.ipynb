# %% [markdown]
# ## Deep Dive #7 - Matrix exponentials

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# What's next, Matrix Taylor expansion?

# %% [markdown]
# ![image.png](attachment:image.png)
