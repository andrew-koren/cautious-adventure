# %% [markdown]
# # Deep Dive #4

# %% [markdown]
# ## Intro

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# With $x_0=0$ the power series expansion is
#
# $$y(x)=\sum_{n=0}^\infty a_nx^n \\ y'(x)=\sum_{n=0}^\infty na_nx^{(n-1)} $$

# %% [markdown]
# (1a) Using the relationship between $y$ and $y'$ we get
# $$
# y' + cy = 0 \\
#
# c\sum_{n=0}^\infty a_nx^n=c\sum_{n=1}^\infty a_{n-1}x^{n-1} \\ %=c\sum_{n=0}^\infty a_{n-1}x^{n-1} -ca_{(-1)}
# \sum_{n=0}^\infty na_nx^{n-1}=\sum_{n=1}^\infty na_nx^{n-1} \\
#
# 0=\sum_{n=0}^\infty na_nx^{n-1} + c\sum_{n=0}^\infty a_nx^n \\
# 0=\sum_{n=1}^\infty na_nx^{n-1}+c\sum_{n=1}^\infty a_{n-1}x^{n-1} \\
# 0=\sum_{n=1}^\infty(na_n+ca_{n-1})x^{n-1}
# $$
# Since each $x^{n-1}$ doesn't interact, each coefficient must also equal zero
#
# $$na_n+ca_{n-1}=0 \\ a_n = -\frac{c}{n}a_{n-1}

# %% [markdown]
# (1b) Using the above formula, we'll derive any $a_n$ in terms of $a_0$. Ideally we'd do a proof by induction but this'll do for me
# $$
# a_1=-ca_0 \\
# a_2 = -\frac{c}{2}a_{1}=\frac{c^2}{2}a_0 \\
# a_3= -\frac{c}{3}a_2=-\frac{c^3}{6}a_0 \\
# a_n = (-1)^n\frac{c^{n}}{n!}a_0
# $$

# %% [markdown]
# (1c)
# $$y(x)=\sum_{n=0}^\infty(-1)^n\frac{c^{n}}{n!}a_0x^n=a_0\sum_{n=0}^\infty\frac{(-cx)^{n}}{n!} \\
# y(x)=a_0e^{-cx}
#  $$

# %% [markdown]
# ## Question 2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (2a)
# $$             y'\left( x \right) = \sum\limits_{n = 1}^\infty  {n{a_n}{x^{n - 1}}} \hspace{0.25in}y''\left( x \right) = \sum\limits_{n = 2}^\infty  {n\left( {n - 1} \right){a_n}{x^{n - 2}}}  \\
#
# 0=\sum\limits_{n = 2}^\infty  {n\left( {n - 1} \right){a_n}{x^{n - 2}}}  + \sum\limits_{n = 0}^\infty  {{a_n}{x^n}}  \\
# $$
# We'll shift down to get the same $x^n$ powers
# $$
# \sum\limits_{n = 0}^\infty  {\left( {n + 2} \right)\left( {n + 1} \right){a_{n + 2}}{x^n}}  + \sum\limits_{n = 0}^\infty  {{a_n}{x^n}}  = 0
# \\
# \sum\limits_{n = 0}^\infty  {( {\left( {n + 2} \right)\left( {n + 1} \right){a_{n + 2}} + {a_n}} ){x^n}}  = 0
# $$
# Again, each coefficient of the power must also be zero
# $$(n+2)(n+1)a_{n+2}+a_n=0 \\ a_{n+2}=-\frac{a_n}{(n+2)(n+1)} \\
# a_n=-\frac{1}{n(n-1)}a_{n-2} $$

# %% [markdown]
# (2b) We'll work through it using the same methods
#
# $$
# {a_2} = \frac{{ - {a_0}}}{{\left( 2 \right)\left( 1 \right)}} \\
# a_4 =  \frac{{{a_0}}}{{\left( 4 \right)\left( 3 \right)\left( 2 \right)\left( 1 \right)}}  \\
# a_{2n} = \frac{(-1)^na_0}{(2n)!}\\
#
#
# {a_3} = \frac{{ - {a_1}}}{{\left( 3 \right)\left( 2 \right)}} \\
# {a_5} = \frac{{{a_1}}}{{\left( 5 \right)\left( 4 \right)\left( 3 \right)\left( 2 \right)}} \\
# a_{2n+1}=\frac{(-1)^na_1}{{(2n+1)}!}
# $$

# %% [markdown]
# (2c)
# We need $a_0$ and $a_1$ before we can get to the $a_n$ stuff
#
# $$y(x)=\sum_{n =0}^\infty a_nx^n=a_0+a_1x+\sum_{n = 2}^\infty \frac{(-1)^na_0}{(2n)!}x^{2n} + \frac{(-1)^na_1}{{(2n+1)}!}x^{2n+1} \\ = a_0\sum_{n = 0}^\infty \frac{(-1)^n}{(2n)!}x^n+a_1\sum_{n = 0}^\infty \frac{(-1)^n}{{(2n+1)}!}x^n \\ = a_0\cos(x)+a_1\sin(x)$$

# %% [markdown]
# ## Question 3
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Hey I know this one from E&M
#
# (3a) Multiply the power series for $y'$ and $y''$ by their variable coefficients
#
# $$
# 2xy'=\sum_{n=1}{\infty}2na_nx^n=\sum_{n=0}{\infty}2na_nx^n\\
# (1-x^2)y''=\sum_{n=2}{\infty}(n)(n-1)a_nx^{n-2}-\sum_{n=2}{\infty}n(n-1)a_nx^n$$
# Do the shift
# $$=\sum_{n=0}{\infty}((n+2)(n+1)a_{n+2}-n(n-1)a_n)x^n$$
# y(x) is trivially $l(l+1)a_nx^n$. With that we've got enough to join all the $e^x$ terms and chew down to the $a_n$ coefficients.
# $$0=(n+2)(n+1)a_{n+2}-n(n-1)a_n-2na_n+l(l+1)a_n \\ a_{n+2}=-\frac{(l-n)(l+n+1)}{(n+1)(n+2)}$$
# (3b)
# Now for the part that really isn't super fun
# $$a_2=-\frac{l(l+1)}{12}a_0 \\
# a_4 = -\frac{(l-2)(l+3)}{12}a_2=\frac{l(l-2)(l+1)(l+3)}{24}a_0 \\
# a_3 = -(l-1)(l_2)/6*a_1 \\
# a_6 = -(l-3)(l+4)/20*a_3=(l-1)(l-3)(l+2)(l+4)/120*a_1$$

# %% [markdown]
# (3c)
# $$
# y_0=1-\frac{l(l+1)}{12}x^2+\frac{l(l-2)(l+1)(l+3)}{24}x^4\\
# y_1=x-(l-1)(l+2)/6*x^3+(l-1)(l-3)(l+2)(l+4)/120*x^5
# $$

# %% [markdown]
# (3d)
# - $P_0(x) = 1-0+0 =1$
# - $P_1(x) = x-0+0=x $
# - $P_2(x) = -1/2(1-\frac{2(3)}{12}x^2+0)=-1/2+\frac{1}{4}x^2$
# - $P_3(x) = -3/2(x-(2)(5)/6*x^3+0)=-3/2*x+15/6x^3$

# %% [markdown]
# Have a great day!
