# %% [markdown]
# # Notes on guide

# %% [markdown]
# ## Part 1: Initial Setup
# This primarily includes optical setup
#
# ![image.png](attachment:image.png)
#
# Double check light polarization? I believe circular polarization should be independent of linear polarizer? 3-8 has a comprehensive guide
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# We should double-check circular polarization by showing it is immune to the angle of the second polarizer

# %% [markdown]
# Also for the plano-convex mirrors we have this
#
# ![image.png](attachment:image.png)
#
# Which says we want 5cm to make the polarizers more efficient
#
# and for the second lens we have
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Part 2: Experiment 4B (p 4-6)
#
# So far we've shown the zero-field transition.
#
# ![image.png](attachment:image.png)
#
# Worth trying out in class? See where field dies out, also a current measurement could be useful for getting thsi done quicker.
#
# ![image-2.png](attachment:image-2.png)
#
# also sounds fun
#
# Also we can try zeroing in the width, but that's optional. Here's how:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Question #1: Earths magnetic field

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Yes, we are asked to measure the strength of the Earth's magnetic field

# %% [markdown]
# Step 4 asks us to read p4-8 through p4-11
# RF gain 4x Oscillator output 0 db
#
# ![image.png](attachment:image.png)
#
# Wait what is the 10kHz Zeeman resonance?

# %% [markdown]
# Also, the manual asks for us to measure $g_F$
#
# ![image.png](attachment:image.png)
