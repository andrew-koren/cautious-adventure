# %% [markdown]
# # Superconductivity

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# [Rezanator Quick Manual](https://d2l.msu.edu/d2l/le/content/2117685/viewContent/15598689/View?ou=2117685)
