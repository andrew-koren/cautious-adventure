# %% [markdown]
# # PS #5 - Eileen

# %% [markdown]
# ![image.png](attachment:image.png) <br>
# ![image-2.png](attachment:image-2.png) <br>
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <!-- Each one of these have the same overall lifetime earnings as in the introduction to the question $W=\$13,000$. Since they have the option to borrow and save freely, illiquid assets do not allow them to control their behavior. Their overconsuming period-2 self can take out a loan equal in value to any illiquid asset and force the loan to be paid for by the illiquid asset once it matures. The consumption in (a-d) will  -->
#
# Each one of these have the same overall lifetime earnings as in the introduction to the question $W=\$13,000$. Since they can no longer borrow, they are able to control the spending of their period 2 self and prevent overconsumption.
#
# (a) Since money can only travel forward through time (unconsumed wealth is sent to next period), In period 1 the individual may purchase a $\$500$ illiquid asset, consume their desired $c_1=\$5000$ and send the remaining $\$500$ to their future self. Their period 2 self has $\$3500+\$500$, which they consume $c_2 =4000$ since they prefer to consume more in period 2 than period 3. Period 3 consumes what is left $c_3=4000$
#
# In (b) and (c) the period-1 self will use similar tactics, only now the income in $Y_2$ is already above $c_2^*$, and will more closely match $c_2^S$. The person's period 1 self will not want to send money to period 2 and will send between $\$1000-\$2000$ to get as close as possible to $c_1^*$ and $c_3^*$. For (b), the period 2 self will consume at least $c_2^S$, since it can make sure $c_2^S$ and $c_1^S$ are met with the minimum payment in period 1. In (c) they consume all wealth since the minimum payment from period 1 already puts $c_3>c_3^S$
#
# In (d) no illiquid assets are used, since $Y_3>c_3^*$

# %% [markdown]
# ![image.png](attachment:image.png)<br>
# ![image-2.png](attachment:image-2.png)<br>
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# In other words you only gain anticipation from consumption in the next two periods. I'd bet recieving the shock in period 3 and 4 are equal? Depends on exponential discounting
#
# (a) I'll do this assuming we are deciding before the event what we'll pay, with knowledege of how it feels.
#
# - Period 1. $u_1=v(shock),\ u_{t>1}=0.\ U^1=v(shock)$
#
# - Period 2. $u_1=\phi v(shock),\ u_2 = v(shock).$<br> $U^1=\phi v(shock)+ \delta v(shock) = (\phi+\delta)v(shock).$ So it is $\phi+\delta$ times as much as immediately recieving the shock
#
# - Period 3. $u_1=u_2=\phi v(shock),\ u_3 =v(shock).$<br> $U^1=(\phi+\delta \phi + \delta^2)v(shock)$
#
# - Period 4. $u_1=0, u_2=u_3=\phi v(shock),\ u_4 =v(shock).$<br> $U^1=(\delta\phi+\delta^2 \phi + \delta^3)v(shock)$

# %% [markdown]
# (b) This result does not hold, as anticipation is only scored for events less than three periods ahead. Willingness to pay will decrease as time goes on beyond 3 periods

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Cool a nice minimalism question.
#
# (a)
