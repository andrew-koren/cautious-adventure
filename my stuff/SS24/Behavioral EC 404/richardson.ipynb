# %% [markdown]
# # Problem Set #2 - Richardson
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 1
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $\alpha =  1-\dfrac{L_0}{L}$ where $L_0$ is the actual loss you will recieve. Thus the loss you recieve as a function of alpha is $$L_0(\alpha)=(1-\alpha)L$$

# %% [markdown]
# ### in class notes related
#
# idk
