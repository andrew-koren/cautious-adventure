# %% [markdown]
# # Thermal Physics

# %% [markdown]
# Chapter 0: Probability
#
# Multiplicity $g(N,n) = \dfrac{N!}{n!(N-n)!} $ This is number of states with value n in an N-sized binary system<br>
# Probability $P_N(n) = \dfrac{g(N,n)}{2^N}$ <br>
#
# Coin flip: N is number of states, n is selected states. <br>
# Flip a coin four times can be represented as four combinations of the possible outcomes $(\uparrow + \downarrow)^4 $. In this notation + means possible state.
#
# Expanding  $(\uparrow + \downarrow)^4 $. $p$ represents outcome $1, q$ represents outcome $2$. If $p+q=1, q=p-1$ You can show in your own time (do this at home!)
# $$(p+q)^n = \sum_{k=0}^{n} \dfrac{n!}{k!(n-k)!} p^k q^{n-k} = \sum_{k=0}^{n} {n \choose k} p^k q^{n-k}$$
#
# We use this equation in class to prove some of the formulas below
#
# mean value $\bar n = <n>$ <br>
# $<n> = np = n(1-q)$
#
# variance $<(\Delta n)^2> = <(n^2-2n \bar n + \bar n ^2)> = <n^2> - \bar n ^2$ mixing notation because we're crazy in here. Next we'll use the binomial expansion on these.
#
# $\Delta n = n- <n>$
#
# $<n^2> = \sum_{n=0}^{N} n^2 P_N(n)=\sum_{n=0}^{N} \dfrac{N!}{n!(N-n)!}n^2p^nq^{N-n}$
#
# use the trick $n^2p^n=p\dfrac{d}{dp}(p\dfrac{d}{dp}(p^n))=(p\dfrac{d}{dp})^2p^n $
#
# $$<n^2>=\dfrac{d}{dp}[p\dfrac{d}{dp}(p+q)^N]=p\dfrac{d}{dp}[pN(p+q)^{N-1}]$$
#
# I kinda lost track at this point ~~#Product rule \$p[N(p+q)^{N-1}+pN(N-1)(o+1)^{N-2}] $~~
#
# Standard deviation $\delta n \equiv \sqrt{<(\Delta n)^2>} = \sqrt{Npq} $
#
# Relative size of fluxuations = $\dfrac{\text{stand. dev.}}{\text{mean}}=\dfrac{\delta n}{\bar n} = \dfrac{\sqrt{Npq}}{Np}=\sqrt{\dfrac{q}{p}}\dfrac{1}{\sqrt{N}}$
# for an even coin that's $1/\sqrt{20}$ for 20 coin flips, which is pretty big (22.3%). For a million that drops down to 0.001
#
# Note: A larger sample size results in a larger standard deviation, however it necessarily scales slower than mean as long as $p \neq 1$

# %% [markdown]
# ## Introductory info

# %% [markdown]
# ### Basics of entropy.
#
# - It adds $\sigma = \sigma _1 + \sigma _2$
# - Two types, practical and ideal, $S = k_b\sigma$. Practical/conventional is related to energy (joules), engines, real world stuff, etc., while $\sigma$ is the math backbone
# - Backbone in number of states,  $\sigma = \log g $
# - $\exp ( \sigma ) = g, $ g is number of systems, $\sigma _1 + \sigma _2 =  \log (g_1 g_2)$
#
# ### Temperature, energy, and entropy
# $$ \dfrac{1}{\tau} \equiv (\dfrac{\partial \sigma}{\partial U})_{N,V}$$
#
# $\tau$ is another math backbone for a real term $T$, which is $\tau = k_b T$. I don't know I think that's a pretty cool explenation for the source of celsius from entropy
#
# ### Probability
# The number of states a system can achieve depends on energy. States $g$ is a function of energy. Assuming each state has equal probability of occuring, number of possible states and probability are correlated. Thus probability ratios can be found from state ratios.

# %% [markdown]
# ### Textbook exampe
# ![image.png](attachment:image.png)

# %% [markdown]
# (2) since $g$ is a function of energy, so's $\exp \sigma$. The notiation is just a bit silly <br>
# (3) Remember entropy and energy transfer are intrinsically related. They call it a taylor expansion because the second term of taylor expansion is basically $\dfrac{\partial}{\partial U_0}$, which is extremely useful because of its relationship to temp. <br>
# (4) Interesting how $\epsilon \text{ and } \tau$ are chilling together. I thought boltzman's constant converted entropy $\sigma$ into energy related entropy $S$
#
# Note equation (3) isn't correct. This is common in thermal physics in general, as equations often only apply if certain simplifications are put into place. Introducing chemical potential we get ![image.png](attachment:image.png)
# which is the fermi-dirac distribution

# %% [markdown]
# Question for the professor: $k_b, \tau, T$ and energy <br>
# Also: notation $ \dfrac{1}{\tau} \equiv (\dfrac{\partial \sigma}{\partial U})_{N,V}$ what about N & V?

# %% [markdown]
# ## Chapter 1
# Binary model systems and average values for harmonic oscillators

# %% [markdown]
# ### Day 2
# includes $g(N,s)$ as a gaussian, $\Delta s$

# %% [markdown]
# Entropy, temperature, free energy
# -> pressure, chemical potency, etc.
#
# What's great about thermal dynamcis is that we can take systems with trillions of particles and simplify them down into these equations.

# %% [markdown]
# Binomial models.
#
# Useful: $N! \sim (2\pi N)^{\frac{1}{2}}N^Ne^{-N+\frac{1}{12N}+...}$

# %% [markdown]
# Excess $2s = N_\uparrow - N_\downarrow$ $$N_\uparrow = \dfrac{N}{2} + s, N_\downarrow = \dfrac{N}{2} + s$$
#
# $g(N,n) = \dfrac{N!}{n!(N-n)!} = \dfrac{N!}{N_\uparrow ! N_\downarrow !}$
#
# $\ln g(N,n) = -\dfrac{1  }{2  }\ln(2\pi N) - (N_\uparrow+\dfrac{  1}{2  })\ln(\dfrac{  N_\uparrow}{N  }) -(N_\downarrow+\dfrac{  1}{2  })\ln(\dfrac{  N_\downarrow}{N  })$
#
# $\ln g(N,s) = \dfrac{1}{2}\ln \dfrac{2}{\pi N} + N \ln 2 - \dfrac{2s^2}{N}+O(\dfrac{1}{N^2})$

# %% [markdown]
# thus we return to g
#
# $$g(N,s) = (\dfrac{2}{\pi N})^{1/2} 2^N e^{- \frac{2s^2}{N}}$$
#
# $$g(N,s) \sim \dfrac{2}{\pi N} 2^N e^{- \frac{2s^2}{N}}$$
#
# This is a gaussian with mean s=0
#
# What are some properties?
#
# $\dfrac{1}{e}=\dfrac{g(N,s)}{g(N,0)}=e^{\dfrac{-2s^2}{N}} \rightarrow s=\sqrt{\dfrac{N}{2}}$
#
# $P_N(s) = \dfrac{g(N,s)}{2^N}$ Normalized? Yeah it kinda normalized itself. ~~Great office hours question~~ nvm he doesn't know
#
# \<s> = 0 <br>
# $<(\Delta s)^2> = <s^2> = \text{maths} = \dfrac{N}{4}$
#
# $\delta s = \sqrt{\dfrac{N}{4}} = \dfrac{\sqrt N}{2} $ very sharply peaked due to avagardo

# %% [markdown]
# ### Day 3

# %% [markdown]
# Energy. Example: magnetic energy $U = -2mBs$. Energy adds of course, and also energy can be negative. An upward oriented magnetic field can have opposite energy of a downward one. Remember: lower case $s$ is excess $s=2(N_\uparrow - N_\downarrow)$
#
# Exchanging energy.
#
# Isolated possible states $g(N,n)$ (or $g(N,s)$) wil multiply.
#
# Initial (before thermal contact):
# Arange field in $N_1 = N_2 = 10$ states
# $$\mathcal{S}_1: N_{1\uparrow}=6, s_1 = 1 $$
# $$\mathcal{S}_2: N_{2\uparrow}=10, s_2 = 5 $$
# $$g_1=g(10,6)=210,\space g_2=g(10,10)=1, \space g_1g_2=210$$
# In thermal contact they even out, eventually enter most probable configuration. Not sure what $\hat S_1$ is, but
# $$\hat S_1 = \hat S_2 = 3: N_{1\uparrow} = N_{2\uparrow} = 8$$
# $$g(10,8)=45, \space (g_1,g_2)_{\text{max}}=45*45=2025 $$

# %% [markdown]
# Back from break
#
# Two spin systems. We're using $g(N,s)$, which is normal-like.
#
# We quickly move to logarithms since the normal curve is full of $e^x$ terms
#
# $ g_1(N_1,s_1)= (\dfrac{2}{\pi N_1})^{1/2} 2^N_1 e^{- \frac{2s_1^2}{N_1}} \def g_1(0)e^{\dfrac{-2s_1^2}{N_1}} $
