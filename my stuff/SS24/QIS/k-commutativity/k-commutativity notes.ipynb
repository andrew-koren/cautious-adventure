# %% [markdown]
# ## Meetings with Ben #2

# %% [markdown]
# ### Notes
# <hr>

# %% [markdown]
# Linear algebra.
# - Similar matricies: have the same determinant, a good if check, and inverse matricies have 1/det of the original. ![image.png](attachment:image.png)
#
# I think a more useful way of thinking about these operations is in the form $AP=PB$. A vector $x$ in A gets sent to $x'$, and is equal to the unitary of a vector in $B$, $x=Py$ <br>
# What's great about these is the fact that $y'$ and $x'$ have similar relationships: $x'=Py'$, as do $y$ and $y'$: $y'=By$, giving us $x' = Py' = PBy$ and $Py'= APy$
#
# Key takeaways for similar matricies: similar matricies have similar vectors, which are still similar after each undergoes matrix multiplication
#
# - Diagonal matricies: They're easy to work with <br>
# ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png)
#
# - Similar diagonal: $A=PDP^{-1}$. How do we obtain P and D?
#
# ![image-4.png](attachment:image-4.png)
#
# Interesting: There's a reason P is a change of basis matrix. For diagonailization, it converts the basis vectors to the eigenvectors of A. Thus, $Pe_1=v_1$. From the diagram above, we also know the diagonal matrix gives the eigenvalues of A.
#
# Example: Matrix $\begin{pmatrix} 3 && 5 \\ -1 && 16 \end{pmatrix}$
#
# $$
# \begin{bmatrix} 3-\lambda && 5 \\ -1 && 16-\lambda \end{bmatrix} = 0\\
# (3-\lambda)(16-\lambda)+5=0 \\
# \lambda = \frac{19}{2} \pm \frac{\sqrt{149}}{2} \\
# Av=\lambda v \\
# \begin{pmatrix} 3 && 5 \\ -1 && 16 \end{pmatrix} \begin{pmatrix} v_1 \\ v_2 \end{pmatrix} = \begin{pmatrix} 3v_1+5v_2 \\ -1v_1+16v_2 \end{pmatrix} = \begin{pmatrix} \lambda v_1 \\ \lambda v_2 \end{pmatrix} \\
# \begin{cases} 3v_1+5v_2=\lambda v_1 \\ -1v_1+16v_2 = \lambda v_2\end{cases} \\
# \begin{cases} 53v_2=\lambda v_1 \\ -1v_1+16v_2 = \lambda v_2\end{cases} \\
# \text{wolfram from here} \\
# v = \frac{1}{2}\begin{pmatrix} 13\mp\sqrt{149}\\ 2 \end{pmatrix}
# $$
#
# From the eigenvalues and eigenvectors we can calculate the change of basis matrix and the diagonal matrix.
#
# $$
# e_1 = \begin{pmatrix} 1 \\ 0 \end{pmatrix}, e_2 = \begin{pmatrix} 0 \\ 1 \end{pmatrix} \\
# P = \frac{1}{2}\begin{pmatrix} 13-\sqrt{149} && 13+\sqrt{149}\\ 2 && 2\end{pmatrix} \\
# D = \begin{pmatrix} \lambda_1 && 0\\ 0 && \lambda_2 \end{pmatrix}
# $$

# %% [markdown]
# This is the unitary U, isn't it? Well we use the clifford unitary to diagonalize pauli strings. It has the property of converting from basis vectors to eigenvectors of the associated pauli string, hence the diagonalization thing.
#
# By definition, a unitary has the property that it's complex conjugate is its own inverse, which is great since complex conjugates are a lot easier to find than inverse matricies.
#
# Okay so in quantum computing we're all about diagonalization, why? It lets us change basis to z-basis for measurements, a necessity for quantum computers. AKA measurement of the paulis that make up a Hamiltonian (btw does that include $c^{[A]}$, the coefficient associated with the pauli string?)

# %% [markdown]
# Tensor Product <br>
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Stabilizer gate - Stabilizers of a spanning set are matricies which return their input if it is within the spanning set.

# %% [markdown]
# ### Questions
# <hr>

# %% [markdown]
# $e^{iA}$. My actual question is why is the taylor approximation 100% accurate for $e^x$ but not any random old function?

# %% [markdown]
# Clifford unitaries
# ![image.png](attachment:image.png)
# What does $\sqrt{Z}$ mean?

# %% [markdown]
# ![image.png](attachment:image.png) why aren't they both depth N?

# %% [markdown]
# Stabilizer circuits
#
# ![image-2.png](attachment:image-2.png)
# <br> okay but stabilizers are also that thing that returns the original qubit string, right?
#
# ![image.png](attachment:image.png)
#
# So span of eigenvectors associated with +1 eigenvalues?

# %% [markdown]
# Why do clifford unitaries diagonalize paulis?
#
# Also $D = UP^{[A]}U^\dag$ is diagonal, so do we undiagonalize afterwards?

# %% [markdown]
# Where does this come from
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Hey wasn't this in Jeremiah's talk?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Answered Questions below here
# <hr>

# %% [markdown]
# ### Exercises
#
# Show eigenvectors of hermetian operators are orthoganal
#
# product of clifford u's is clifford u
#
# Are pauli strings unique?

# %% [markdown]
# ### Live notes
#
# pauli strings are hermetian

# %% [markdown]
# ## Meeting with Ben #3

# %% [markdown]
# Universal: any unitary is possible
#
# Transversal Gates: X gate to entire state
#
# Logical state: $\Psi$ -> physical: qubits
#
# Non-transversal: acts on not all qubits, deeper. You can trick them with a T-state, but that takes time

# %% [markdown]
# Pure state density is just projector, mixed state is sum of $p_i$ states -> you actually need stat mech for mixed & quantum
#
# Homework: partial trace -> just the system, unentangled from the environment -> schmit decomposition exists for all bipartate
#
# Homework: unpickle

# %% [markdown]
# Basic quantum: projector?

# %% [markdown]
# Today we did graphs. Greedy algorithms make the best choice now and say thats the best for the future, but crawford does better.
#
# Remember stabilizer matricies are the [-], which can represent any pauli. Each gaussian elimination corresponds to a clifford U, which together is the diagonalizing matrix. Tabalau is a better name for stabilizer
#
# Remember the diagonalized is used to measure the paulis, cuz **diagonal paulis are in the z basis**
# - Since matrix representation of an n - qubit pauli is represented by a tableau of length 2n, a diagonal tableau has entries only in the first half of rows, resulting in an all z tableau
# <hr>

# %% [markdown]
# ## Meeting with Ben #4

# %% [markdown]
# Why is the first bucket biggest? 1. Try permuting 2. Why does this algorithm work better than random?

# %% [markdown]
# ## Meeting with Ben #5

# %% [markdown]
# Why do k-commuting buckets from SI also fully commute -> because if they k-commute they c*k commute -> $16=2*8$ Shouldn't we create k-commuting tabelaus? Like if k=2, 16 qubit, doesn't that mean we need 8 tableaus
#
# Still trying to figure out what contradictory means

# %% [markdown]
# Row operations on tableau. How do you have elements which aren't x or z? How exactly are tableaus set up? Why does stim turn a single pauli string diagonal?
#
# Need to gather definitions, I wish there was a source for them

# %% [markdown]
# Clifford unitaries turn pauli strings into pauli strings

# %% [markdown]
# Abelian = commutative group

# %% [markdown]
# Stabilizer: $C|0>^n=\psi \implies P_i \psi = +\psi$
#
# We want $C'P_iC'^\dag = D_i$

# %% [markdown]
# ### Spring Break

# %% [markdown]
# Operations used to diagonalize a tableau are clifford, so the big [] circuits are actually a bunch of gates. Prove that elementary matrix operations can be done using clifford gates?

# %%
import stim
had = stim.Tableau.from_named_gate('H')
cnot = stim.Tableau.from_named_gate('CNOT')
sgyatt = stim.Tableau.from_named_gate('S')
had(stim.PauliString('X'))

sgyatt(stim.PauliString('Y'))
# Out:
# stim.PauliString("-X")

# %% [markdown]
# It appears stim stabilizers (tableaus) are stored according to the conjugate they produce (tableau H(X) yields Z and $HXH^\dag=Z$ ). If I want to do this portion of the project, I should be more concerned about the Gram-Schmidt procedure than learning about Stim. Stim turns tableaus into circuits, tableaus should have the diagonalization pre-baked into them.

# %% [markdown]
# Lets try copying the paper, step-by-step
#
# ![image.png](attachment:image.png)
#
# We have $\mathcal{G}_i$ and its operators $\hat P$.
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# Okay, what do we do with these?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Independent generators of the group. Cool. Here's how Gram-Schmidt is done using gauss-jordan elimination, which should do the job for these tableaus. ![image.png](attachment:image.png)

# %% [markdown]
# Each pauli would be represented as two row vectors? Or tow column vectors? I can figure this out. Either way, we're still trying to impliment this via stim.
# ![image.png](attachment:image.png)

# %% [markdown]
# So we're making a stabilizer group which the paper goes on to describe in part 3. Lets try creating the tableaus according to the paper and chucking them into stim tableaus?

# %%
tab = stim.Tableau.from_stabilizers([
    stim.PauliString("XX"),
    stim.PauliString("ZZ"),
])

tab.z_output(1)
# Out:
# stim.PauliString("+ZZ")

# %% [markdown]
# ## Notes on Ansatz

# %% [markdown]
# Intro:
#
# ![image.png](attachment:image.png)
#
# Quantum Chemistry - Hamiltonians describe the energies that molecules can have
# - o2, NaLi, N2, HF, etc
#
# As I understand it, we want to transform the |HF> state to the the ground state using the ansatz.
#
# Hamiltonians can be broken down into pauli strings, currently we get them from a library hamlib. We group these strings, diagonalize them, and apply rotations to get to the ground state. Our k-commutativity alg does this quicker
#
#
# Other ideas: <br>
# Clifford gates are easily simulated on classical computers

# %% [markdown]
# ## Meeting with Ben #6

# %% [markdown]
# Now we have our diagonalizing circuits, we want to pump it into Anand + Brown's code.
# 1. Get chemical hamiltonians from original paper
# 2. use our k-commuting method to diagonalize
# 3. Tequila VQE

# %% [markdown]
# 1. get computer running
# 2. linux? - windows subsystem for linux ubuntu
# 3. spend an hour doing cirq tutorial
#     - U_g, parameters, U\dag
#     - repeat
# 4. Build ansatz circuit
# 5. root search lowest value
# 6. scipy optimizer
#
# Start with full commuting -> k-commuting

# %% [markdown]
# ## Meeting with Ben #7
