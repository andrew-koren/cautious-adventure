# %% [markdown]
# # Lecture 1 (wk 1)
# Introduction/overview

# %% [markdown]
# 1.
# 803 grading: Exams, papers, and homework are ~even
#
# Topic selection Feb 14, outline due end of month

# %% [markdown]
# Standard model: Quarks, Leptons & force carriers (bosons)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lecture 2
#
# More on each particle
#
# - fermions are spin 1/2
# - leptons do not use the strong force
# - quarks are always bundled
# - antiparticles have same mass, spin. everything else is flipped.
# - neutrals are their own antiparticle
#
# Data tables on quantum numbers
