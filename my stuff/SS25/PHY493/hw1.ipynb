# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# There can be multiple violations in each example, so watch out.
#
# (a) Clearly a violation of lepton flavor. Also, wouldn't an on-shell photon have no energy to contributre to the electron and antimuon mass?
#
# (b) The on-shell $W^+$ boson has less mass than a top quark, so this cannot occur. I think weak interactions don't care about quark flavor conservation
#
# (c) Charge and lepton flavor violation.
#
# (d) Acceptable. Quark flavor is fine due to weak force
#
# (e) Lepton flavor violation. Would be fine if positron or antineutrino.
#
# (f) Energy violation again with an on-shell photon.
#
# (g) quark flavor violation, no weak forces seen here. Also lepton flavor
#
# (h) energy violation, $Z$ is much heavier than $\overline{b}$

# %% [markdown]
# Let's identify each of these particles. Mass in GeV/c^2
#
# $\gamma$ photon mass:0 charge:0 <br>
# $e^-$ electron mass:0.000511 <br>
# $\mu^+$ antimuon mass:0.106
#
# $W^+$ W boson mass:80.39 charge:+1 <br>
# $t$ top quark mass:173.1 charge:+2/3<br>
# $\overline{b}$ anti-bottom quark mass:4.18 charge: +1/3
#
# $Z^0$ Z Boson mass:91.19
#
# $b$ bottom quark mass:4.18 charge: -1/3
#
# $W^-$ W boson mass:80.39 charge:-1 <br>
# $\nu_e$ electron neutrino mass:small, charge:0
#
# $\tau^-$ tau mass:1.777 charge:-1 <br>
# $\tau^+$ tau mass:1.777 charge:+1
#
# $c$ charm quark mass:1.28 charge:+2/3
#
# $\overline{s}$ antistrange quark mass: 0.1 charge:+1/3

# %% [markdown]
# <!-- answers
#
# (a)
# - lepton number <br>
# lepton number is violated, $L_e$ and $L_\mu$ go from (0,0) to (1,-1)
#
# (b)
# - energy conservation <br>
# The $W^+$ boson doesn't have enough mass for the top quark $80.39 GeV/c^2 < 173.1 GeV/c^2$
#
# Looks like everything else is conserved, so some additional energy could make this possible (off-shell)
#
# (c)
# - energy conservation (acceptable) <br>
# The $Z^0$ boson mass is much larger than the rest mass of each muon $91.19 >> 0.212$. This is fine as long as excess energy becomes kinetic
# - lepton number <br>
# would be fine if $\mu^+$ and $\mu^-$, instead we have +2 $L_\mu$ after the decay
# - charge conservation <br>
# $0 \rightarrow +2$
#
# (d)
# - energy conservation (acceptable) <br>
# Excess energy must go somewhere. The bottom quark has 4.18 GeV/c^2, and $173.1 > 80.39 + 4.18$
#
# Flipping the antibottom quark to bottom quark means that everything else is conserved, same as in (b)
#
# (e)
# - energy conservation (acceptable) <br>
# $W^-$ is much more massive than the electron and neutrino, so excess mass must be converted to kinetic energy $80.39 > 0.000511 + \nu_e$
# - lepton number <br>
# $L_e$ goes from zero to two, since a regular neutrino is produced. An antineutrino would balance this.
#
# (f)
# - energy conservation <br>
# On-shell photons cannot produce mass. More like momentum conservation. -->

# %% [markdown]
# ![image.png](attachment:image.png) <br> ![image-2.png](attachment:image-2.png)

# %% [markdown]
# (a) charge violation -1 to -2.
#
# (b)
#
# (c)

# %% [markdown]
# Hadron descriptions
#
# $\Omega^-$ $sss$ 1.6 GeV/c^2 <br>
# $\Xi^-$ $dss$ 1.3 GeV/c^2 <br>
# $\pi^-$ $\overline{u} d$ .14 GeV/c^2
#
# $\Sigma^+$ $uus$ 1.2 Gev/c^2<br>
# $\pi^0$ $u\overline{u}$ or $d\overline{d}$ .13 GeV/c^2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This question asks what the odds are that helium atoms hit gold atoms and scatter at a $45\degree$ angle. Hyperphysics has a pretty good walkthrough of this problem
#
# ![image.png](attachment:image.png)
#
# We've got all of our variables, and can convert gold density to molarity. The only part not in the equation is the detector transverse area. I assume we'll have to sweep through the angle $\pi/4 \pm 0.5 \text{cm}$

# %% [markdown]
# ![image.png](attachment:image.png)
