# %% [markdown]
# <details> <summary> Q1 </summary>
#
# ![image.png](attachment:image.png)
#
# </details>

# %% [markdown]
# $$
# f = \frac{1}{e^{(\epsilon-\mu)/\tau}+1} \\
# \frac{df}{d\epsilon} = \frac{\frac{1}{\tau} e^{(\epsilon-\mu)/\tau}}{-\left(e^{(\epsilon-\mu)/\tau}\right)^2} \\
# \epsilon = \mu \rightarrow \frac{\frac{1}{\tau}}{-2^2} \\
# - \frac{df}{d\epsilon}= \frac{1}{4\tau}
# $$

# %% [markdown]
# <details> <summary> Q2 </summary>
#
# ![image.png](attachment:image.png)
#
# </details>

# %% [markdown]
# $$
# f(\mu + \delta) = \frac{1}{e^{(\mu + \delta - \mu)/\tau} +1} = \frac{1}{e^{\delta/\tau} + 1}
# = \frac{e^{-\delta/\tau}}{1+e^{-\delta/\tau}} \\
# 1- f(\mu - \delta) = 1- \frac{1}{e^{-\delta/\tau} + 1}
# = \frac{1+e^{-\delta/\tau}-2}{1+e^{-\delta/\tau}} = f(\mu+\delta)
# $$

# %% [markdown]
# <details> <summary> Q3 </summary>
#
# ![image.png](attachment:image.png)
#
# </details>

# %% [markdown]
# <details> <summary> Q4 </summary>
#
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)
#
# </details>

# %% [markdown]
# <details> <summary> Q5 </summary>
#
# ![image.png](attachment:image.png)
#
# </details>

# %% [markdown]
# <details> <summary> Q6 </summary>
#
# ![image.png](attachment:image.png)
#
# </details>
