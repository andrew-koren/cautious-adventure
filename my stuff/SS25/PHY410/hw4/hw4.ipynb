# %% [markdown]
# <details> <summary> Q1 </summary>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Helmholtz free energy $F(\tau) = U - \tau \sigma$
#
# $U = \langle \epsilon \rangle = \epsilon/2$
#
# Is $Z$ a canonical ensemble only thing?

# %% [markdown]
# <details> <summary> Q2 </summary>
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <details> <summary> Q3 </summary>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <details> <summary> Q4 </summary>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <details> <summary> Q5 </summary>
#
# ![image.png](attachment:image.png)
