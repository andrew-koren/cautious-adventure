# %% [markdown]
# # Phy 481 - Electrodynamics

# %% [markdown]
# ![image.png](attachment:image.png)
#
# $$
# A \times B = \left| \begin{matrix} \hat x & \hat y & \hat z \\ A_x & A_y & A_z \\ B_x & B_y & B_z\end{matrix} \right|
# $$

# %% [markdown]
# ## General Notes

# %% [markdown]
# The Fundamental Theorem for Gradients
#
# $$
# \int_{\vec a}^{\vec b} \left( \vec \nabla V \right) \cdot d \vec l = V(\vec b) - V(\vec a)
# $$
#
# This is because the potential of a scalar is a vector, and the path integral just goes from A to B, and potential is path independent.

# %% [markdown]
# How do we do the path integral?
#
# $$
# \oint \vec E \cdot d\vec l \text{ bounded by} \\
# \left\{(x,y): 0 \leq x \leq 1, 2 \leq y \leq 2x \right\}\\
# \text{where } \vec E = (x^2 - y^2)\hat x + 2xy \hat y\\
# d\vec l = d x \hat x + dy \hat y
# $$
#
# Break it apart into a double integral

# %% [markdown]
# Option 2: use stokes theorem when area is easy
#
# $$
# \oint \vec E \cdot d\vec l = \int_S ( \vec \nabla \times \vec  E) \cdot d\vec a \\
# $$
#
# For $\vec E = (x^2-y^2) \hat x + 2xy \hat y$, the path on $0 \leq x \leq 1, 2x^2 \leq y \leq 2x$ (ccw) can be annoying. <br> You do some substitution with $y = 2x - y=2x^2$ and a double integral stuff. Or you just find a determinant
#
# $$
# \left|  \vec \nabla \times \vec  E \right| = \left| \begin{matrix} \hat x & \hat y & \hat z \\ \frac{\partial}{\partial x} &\frac{\partial}{\partial y} &\frac{\partial}{\partial z} \\ x^2-y^2 & 2xy & 0\end{matrix}\right| = 4y \hat z \\
# \oint \vec E \cdot d\vec l = \int_0^1 \int_{y=2x^2}^{y=2x} 4y dy dx = \int_0^1 \left. 2y^2\right|_{2x^2}^{2x} dx \\ = \int_0^1 \left(8x^2-8x^4\right) dx = \left. \frac{8}{3}x^3 - \frac{8}{5}x^5 \right|_0^1 = 16/15
# $$

# %% [markdown]
# $\uparrow$ <br>
# Shawn<br>

# %% [markdown]
# ## Integral guide

# %% [markdown]
# Path integral: use the path function to convert to a single variable
#
# Surface integral (simple): same as path, only with double integral instead. Good for surfaces that are easy to describe in some coordinate system

# %% [markdown]
# ## Dirac Delta
#
# We can convert from surface integrals to volume integrals, etc. using dirac delta.
#
# Point charge $\leftrightarrow$ volume charge density
#
# $3Q$ at $(3, -1, 3) =$
# $$
# 3Q = \int_V \sigma \delta(x-3)\delta(y+1)\delta(z-3) dx dy dz \\
# 3Q = \sigma
# $$
# The volume charge density has value $3Q$

# %% [markdown]
# ## Select Problems

# %% [markdown]
# Consider a thick shell with charge density
#
# $$
# \rho = \frac{k}{r^2}, a < r<b
# $$
#
# Make $|E|$ as a function of $r$. We need to convert this charge density into an electric field vector.
#
# $E = k\frac{q}{r^2}$
#
# $$
# \oint_S \vec E \cdot d\vec a = k \int_V \rho dV
# $$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# 1st equation: the average electric field on a boundary depends on the charge enclosed by the boundary (see integral form)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Example 2: cylindrical coordinates. $dV = r dr d\theta dz$
#
# A coax cable hase a uniform volume charge radius $a$ and uniform suface charge radius $b>a$. The cable emits no electric field.
#
# In order to use $\oint \vec E \cdot d \vec a$, we need to reconcile/zero out the annoying sides
#
# $$
# Q(r) = \begin{cases}
# \rho z\pi r^2 & r < a \\
# \rho z\pi a^2 & a < r < b \\
# 0 & r > b
# \end{cases}
# $$
#
# Area
# $$
# \int_{\text{side}} E \cdot da = E (z2\pi r)
# $$
# This lets us find $E$
# $$
# \frac{Q(r)}{\epsilon_0} = E (z2\pi r) \\
# E = \frac{1}{z}\frac{Q(r)}{2\pi r\epsilon_0} \\
# = \begin{cases}
# \frac{\rho r}{2 \epsilon_0} & r < a \\
# \frac{\rho a^2}{2 r \epsilon_0} & a < r < b \\
# 0 & r > b
# \end{cases}
# $$

# %% [markdown]
# What about a flat infinite plane of charge? $\vec E = \frac{\sigma}{2\epsilon_0} \hat n$. This comes from using a flat gaussian surface.
