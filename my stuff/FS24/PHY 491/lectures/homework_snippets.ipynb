# %% [markdown]
# # Homework Snippets
# I'll put in some relevant problems, solutions, and formulas from both my work and the answer keys based on what I think will be on the quiz.

# %%
from scipy.constants import hbar, electron_mass, pi

#pi**2*(hbar**2)/(2*electron_mass*)
49/4*13.6
# Out:
# 166.6

# %% [markdown]
# # Answer keys

# %% [markdown]
# <details>
# <summary>Variational method</summary>
#
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# </details>
#
# <details>
# <summary>Ionization w/screening assumption</summary>
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# Classically forbidden: E < V(r)
#
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
#
# </details>

# %% [markdown]
# <details>
# <summary>Spectroscopic notation</summary>
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# </details>
#
# <details>
# <summary>Reciprocal space basics</summary>
#
# Reciprocal lattice shape is same as direct, ony rotated by difference between ai and bi
#
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
#
# </details>

# %%
from numpy import array, sin, pi

th2= array([26.815, 38.119, 46.842, 54.647, 61.714])
th = th2/2

lbd = 1.5406

d = lbd/(2*sin(th*(2*pi)/360))
d[0]**2/(d**2)*1
# Out:
# array([1.        , 1.98330859, 2.93853644, 3.91870968, 4.89273626])

# %%
3.32/(10**(1/2))
# Out:
# 1.0498761831759018

# %%
th*(2*pi)/360
# Out:
# array([0.23387412, 0.33248522, 0.40840704, 0.47647489, 0.53843407])

# %%
pi/2
# Out:
# 1.5707963267948966

# %%
# Out:
# array([0.23387412, 0.33248522, 0.40840704, 0.47647489, 0.53843407])

# %% [markdown]
# <details>
# <summary>BZ</summary>
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# </details>
#
# <details>
# <summary>Phonons</summary>
#
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# </details>

# %% [markdown]
# # My results

# %% [markdown]
# ## Hw1
#
# Likely some new strange hydrogenoid

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# From answers:<br>
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Variational Method: no crazy integrals remember. Just go with the flow and follow your heart. Normalize & expectation value

# %% [markdown]
# ## Hw 2
#
# Shielding & more quantum
#
# I failed this homework. Forbidden zone: E < V
#
# I also failed to do a simple hydrogen 1s wavefunction

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# R = 13.6eV

# %% [markdown]
# I have no idea why he assumes that $\Psi$ is constant. Maybe becasue the radius is so small.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Things I might forget: spherical integral
#
# ![image.png](attachment:image.png)

# %% [markdown]
# High energy: close to atom

# %% [markdown]
# HW3:
#
# Paramagnetism: Remember the formula in notes? Yeah more angular momentum -> more paramagnetic
