# %% [markdown]
# # Hydrogen

# %% [markdown]
# Basic hamiltonian
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Chapter 2 - points (arranged)

# %%
from numpy import sqrt, arcsin, pi

arcsin(1.5406 *sqrt(6)/(2*3.9045)) * 360/(2*pi)
# Out:
# 28.897751999867985

# %% [markdown]
# # Chapter 3 - Electrons
#
# ![image-5.png](attachment:image-5.png) The method: $\vec b_1$ is $\beta \begin{pmatrix} a_2 \\ -a_1 \end{pmatrix}$, show $b_1 \cdot a_1 = 2\pi$ and $b_1 \cdot a_2 = 0$
#
# Alternative method: ![image-7.png](attachment:image-7.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
