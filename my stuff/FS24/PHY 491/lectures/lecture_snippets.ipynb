# %% [markdown]
# # Hydrogen

# %% [markdown]
# Basic hamiltonian
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Chapter 2 - points (arranged)
