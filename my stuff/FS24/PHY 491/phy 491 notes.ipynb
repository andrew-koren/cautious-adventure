# %% [markdown]
# # Phy 491 - Condensed Matter Physics
# building from the bottom up

# %% [markdown]
# ## 1. The Hydrogen Atom

# %% [markdown]
# Reading: Mcintyre 7, 8, (9)

# %% [markdown]
# 1. The hydrogen atom
#
# Since the quantum is too complicated to be fun, we'll use center of mass coordinates
#
# $$
# \vec x = \dfrac{m_e \vec{x}_e + m_n \vec{x}_n}{m_e+m_n} \quad \text{center of mass} \\
# \vec r = \vec x_e - \vec x_n \quad \text{electron mass is small}
# $$
#
#
# Note: it's so complicated, I don't even want to type. Add details showing the quantum mechanics here once the notes are released

# %% [markdown]
# $$
# \frac{\partial}{\partial\vec x_e} =\frac{\partial\vec x}{\partial\vec x_e} \frac{\partial}{\partial\vec x} + \frac{\partial\vec r}{\partial\vec x_e} \frac{\partial}{\partial\vec r} \\
#
# = \frac{m_e}{m_e + m_n} \frac{\partial}{\partial\vec x} + \frac{\partial}{\partial\vec r}
# $$
#
# $$
# \nabla_{x_e}^2 = \left( \frac{m_e}{m_e+m_n} \right)^2 \nabla_{x}^2 + \nabla_{r}^2 + \frac{2m_n}{m_e+m_n}\frac{\partial ^2}{\partial \vec x \partial \vec r}
# $$
#
# Too slow. Again, gotta come back when notes are out
#
# $$
# \nabla_{x_n}^2 = \left( \frac{m_n}{m_e+m_n} \right)^2 \nabla_{x}^2 + \nabla_{r}^2 - \frac{2m_n}{m_e+m_n}\frac{\partial ^2}{\partial \vec x \partial \vec r}
#
# $$

# %% [markdown]
# $$
#
# \frac{1}{m_e} \nabla_{x_e}^2 + \frac{1}{m_n}\nabla_{x_n}^2 \\
# = \frac{m_e+m_n}{\left(m_e+m_n\right)^2} \nabla_x^2 + \left(\frac{1}{m_e} +  \frac{1}{m_n}\right)\nabla_r^2 \\
# = \frac{1}{m_e+m_n}\nabla_x^2+\frac{1}{\mu} \nabla_r^2
# $$
# Reduced mass helps keep clutter out of equations. I think that refers to $\mu = \frac{1}{m_e}+\frac{1}{m_n}$

# %% [markdown]
# The new hamiltonian H is
#
# $$
# H = -\frac{\hbar^2}{2(m_e+m_n)}\nabla_x^2-\frac{\hbar^2}{2\mu}\nabla_r^2-\frac{ze^2}{4\pi \epsilon_o |\vec r|} \\
# \quad \quad H_k \hspace{2cm} H_r
# $$
#
# We find $H$, $H_k$, and $H_r$ all commute. We remember that there's a complete set of mutual eigenstates shared between the three.

# %% [markdown]
# $H_k$ is the kinetic energy of the free particle (the hydrogen atom in space)
#
# $H_r$ describes how the energy of the system changes with the separation of the proton and electron.

# %% [markdown]
# $H_r |E_r \rangle = E_r |E_r \rangle$ -see mcintyre
#
# $$-\nabla_r^2 = \frac{P_r^2}{\hbar^2}+\frac{L^2}{r^2} \\ \text{radial KE and tangential KE}$$
#
# $P_r =-i \hbar \left(\frac{\partial}{\partial r} + \frac{1}{r}\right)$ from 471

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Multi-electron atoms

# %% [markdown]
# Week 2 - Spectroscopy
#
# Spectral lines (hydrogen is pretty solid)
#
# Lyman $n=2,3,4 \rightarrow n'=1$  <br>
# Balmer $n=3,4,5\rightarrow'=2$ <br>
# Paschen $n=4,5\rightarrow n'=3$
#
# Principal quantum number $n$: maximum angular momentum for a state depending on the energy there $\mathcal{L} = n-1$
#
# Note that there is no angular momentum without energy $n=1$
#
# Classical similarity: a state with no momentum is just a straight line (fall through planet). Or I like to imagine it's a donut.
#
# $n=2 \rightarrow \mathcal{L}=1 \ \{1, 0, -1 \}$

# %% [markdown]
# The eigenfunctions/wavefunctions of hydrogen
#
# $\langle \vec x| E|L\rangle = U_n^l(r) \cdot y_e^m (\phi, \theta)$
#
# I did this in my review! $y_e^m = Ne^{im\phi} p_e^m \cos\theta $ <- Legandre Polynomial (see Mcintyre)
#
# $$
# u_n^l = -A_n^l e^{-\rho} Z\rho^{l} L_{n+l}^{2l+1}(2\rho)
# $$
# with
# $$
# \rho = \frac{zr}{ma_0}\\
# A_n^l=\left(\frac{z\rho}{r}\right)^{3/2} \sqrt{\frac{(n-l-1)!}{2n[(n+l)!]^3}} \\
# L_{n+e}^{2l+1} = e^r r^{-2(l+1)}/(n+l)! \frac{d^{n+l}}{dr^{n+l}}(e^{-r}r^{(n+l)+(2l+1)})
# $$

# %% [markdown]
# Exotic atoms: muonium, hadronic hydrogen, positronium <br> These are actually still described by the model of Hydrogen
#
# Quasiparticles: holes, excitations
#
# Highly ionized systems: regular atom with electron removed
#
# Multi-electron systems (needs corrections)

# %% [markdown]
# Multi-electron atoms.
#
# Qualitative similarity: Orbitals have the same shape (spdf)
#
# Difference: Hydrogen binding energy is quite strong since lower orbitals have a greater core potential <br>
# example: $n=2\rightarrow n'=1$ <br>
# H $L \ \alpha = 121nm = 10.2eV$ (uv) <br>
# Cu $K \ \alpha = 0.15nm = 8.04 keV$ (x-ray)
#
# Ionization differes because of shielding and coulomb repulsion between electrons. This results in solutions being analytically impossible.
#
# $$H = \frac{p_1^2}{2m}-\frac{2e^2}{r_1}+\frac{p_2^2}{2m}-\frac{2e^2}{r_2}+\frac{e^2}{|r_1-r_2|}$$
#
# Shielding $Z_{eff}$ not all the positive charge gets out to the electrons, since the negative charge of inner electrons cancels it out. If you make an assumption about which electrons are shielding, state it.<br>
# Example $z_{eff} = z + (n-1)q$ for all electrons shield

# %% [markdown]
# In reality, usually a bit off because of orbital overlap.
#
# Example: $E_1^{exp} = 3.94 * 10^{-18} J \rightarrow z_{eff} = 1.34$
#
# Density functional theory DFT $\rightarrow$ effective potential $c$ "pseudo-potential" from experimental results.
#
# $\rightarrow$ need more than n to describe energy. n, l needed due to radial distributions.

# %% [markdown]
# ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Higher probabiltiy to find $e^-$ near nucleus implies less shielding (can't shield if it's under the shield)

# %% [markdown]
# Electron configurations and the periodic table: taking spin into consideration.
#
# Fill lowest energy first and new stuff:
#
# 2.1 PEP: Two or more identicle particles with half-spin (electrons) cannot occupy the same orbital

# %% [markdown]
# Rules (cont but the professor has a migrane)
#
# $2.2 L = \sum l_i$ is maximized (after PEP). Hund's rules minimizes coulomb repulsion by spreaing electrons out from the same orbitals. Also interaction with nucleus is maximized since they're shielding each other less.
#
# Example Pr 4f shell - [Xe]$4f^36s^2$
# $$
# m_l = -3 \ -2 \ -1 \ 0 \ 1^\times\ 2^\times\ 3^\times
# $$
#
# $\sum l_i = 6$ and $\sum s_i = \frac{3}{2}$
#
# $2.3$ relative alignment of $\vec L$ and $\vec s$ is parallel (pos/neg)
# $|J| = |L| \pm |S|$
#
# Sodium S = 1/2 L -0, J-1\2 $\rightarrow \ ^2S_{1/2}$
#
# Manganese Mn. An outlier cuz we're in chemistry world. Should be [Ar]$4s^23d^5$ but shielding and interactions push the orbitals around. Instead it's switched around. This is chemistry world where rules have exceptions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Magnetism
#
# Atomic Magnetism aka what I did in advanced lab
#
# We are basically interested in magnetization, susceptiblity, and permeability
#
# $$
# \vec M = \frac{\chi}{\mu_0} \vec B
# $$
#
# Hamiltonian for magnetic interaction:
# $$
# \begin{matrix}
# H &=& H_0 &+& \mu_B \vec B (\vec l + g \vec s) &+& \frac{l^2}{2m}\vec A ^2 \\
# &&&&\text{paramagnetic/zeeman term}&&\text{diamagnetic term}
# \end{matrix} \\
# \\ \text{where } \vec \nabla \times \vec A = \vec B
# $$
#
# $H_0$ is just the KE and PE we've been discussing. $g \approx 2$ Theparamagnetic term can be rewritten as
# $$
# \vec \mu_B \vec B (\vec l + g \vec s) = g_{\text{eff}} \mu_B \vec B \vec J
# $$
# Then the system is damagntic for $J =0$ else paramagnetic

# %% [markdown]
# Purely hypothetical: its probably paramagnetic
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now we're done with atomic physics!

# %% [markdown]
# ### Molecules
# Molecules are the most trivial systems (atoms condensed together)
#
# See Demtroeder "Atoms, Molecules, and Photons" Chp 9
#
# The $H_2$ atom
#
# $$
# H \Psi(r_1,r_2, R_A, R_B) = E\Psi \\
# H = -\frac{\hbar^2}{2M_A}\nabla_A^2-\frac{\hbar^2}{2M_B}\nabla_B^2-\frac{\hbar^2}{2m_e}\nabla_1^2-\frac{\hbar^2}{2m_e}\nabla_2^2 \\
# -\frac{z_Ae^2}{4\pi\epsilon_0 r_{1A}}-\frac{z_Be^2}{4\pi\epsilon_0 r_{1A}}-\frac{z_Ae^2}{4\pi\epsilon_0 r_{2A}}-\frac{z_Ae^2}{4\pi\epsilon_0 r_{2B}}
# $$

# %% [markdown]
# Or in Hartree units:
# $$
# H = -\frac{1}{2M_A}\nabla_A^2-\frac{1}{2M_B}\nabla_B^2-\frac{1}{2m_e}\nabla_1^2-\frac{1}{2m_e}\nabla_2^2 \\
# -\frac{z_A}{ r_{1A}}-\frac{z_B}{ r_{1A}}-\frac{z_A}{ r_{2A}}-\frac{z_A}{ r_{2B}}+\frac{1}{r_{12}}+\frac{z_Az_B}{R_{AB}}
# $$

# %% [markdown]
# Born-Oppenheimer approximation (works alright for equilibrium systems)
# - Find distance
# - Measure
# - Repeat
# - Find minimum
#
# Because $M_N >> m_e \rightarrow T_n=0$. Now $\Psi(r_1,r_2,R_A,R_B) = \Psi_{e}^{R_{AB}} (r_1,r_2)\Psi_N(R_A,R_B)$

# %% [markdown]
# $H_{\text{elec}} \Psi_e = E_e (R_A, R_B)\Psi_e $
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Spoiler alert: we won't be solving this

# %% [markdown]
# Molecular orbital diagrams & LCAO (Linear combinations of Atomic Orbitals)
#
# ![image.png](attachment:image.png)
#
# If there are equally many bonding and antibonding occupied states, there is no energetic advantage to binding

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Some orbitals are the same direction, others are opposites
#
# ![image.png](attachment:image.png)
#
# To understand, consider the hydrogen atom's orbitals. They superimpose in multi-nucleus systems, which push and pull electrons in all different directions.

# %% [markdown]
# In chemistry world, rules are loosy-goosey. The professor is currently looking at big red & green blobs right now. Inversion symmetry at every point determines if there is bonding or antibonding ($g$ and $u$) (also sometimes not $g$ and $u$). Bonding axis splits the molecule. $u$ symmetry can be bonding depending on axis. All the important cases should be committed to memory from his 9/16 notes.

# %% [markdown]
# Some notes:
#
# $\sigma$-orbitals have $e^-$ density on bond axis, while $\pi$ orbitals do not. $\sigma_g / \pi_{g*}$ are inversion symmetric, while $\sigma_u / \pi_u$ do not
#
# Flourine gas: see drawing
#
# ![image.png](attachment:image.png)

# %% [markdown]
# bond orders:
#
# $$
# B = \frac{\text{number of bonding } e^- - \text{number of antibonding }e^-}{2} \\
# \text{F2: }B = \frac{10-8}{2} = \frac{2}{2} = 1
# $$

# %% [markdown]
# Spectroscopic notation aka molecular term symbols
#
# $$
# \ ^{2S+1}\Lambda_{g,u}
# $$
#
# $\Lambda$ in exchange for angular momentum l. $SPDF \rightarrow \Sigma 0, \Pi 1, \Delta 2, \Phi 3$ <br>
# This remains the sum of individual orbital momenta $\Lambda = \sum_i \lambda_i $
#
# $g$ <br>
# $u$

# %% [markdown]
# ## Quiz #1 Q&A
#
# Meta-question: in past years, what did students typically ask about during q&a's?
#
# You said the quiz isn't going to be integral intense, are you going to give us some integrals?

# %% [markdown]
# Be comfortable with electron configurations
#
# Be comfortable with magnetization
#
# We're not doing extensive calculations
#
# No ferromagnetism
#
# There is Homework 3 on it.
#
# Atomic magnetism: Paramagnetism or diamagnetism
#
# - How to get $\pi_g^*$: <br>
# Lecture 7. Think about the red and green circles (and memorize)<br>
# Star: andtibonding.<br>
# Is electron density on the symmetry axis? Note that bonding and anti-bonding are always the same type.<br>
# $\sigma$: Is along axis<br>
# $\pi$: Is weird. <br>
#
# Lecture 8. $P_x$ and $P_y$ are weird burger bonds **with no electrons on bond axis** result in $\pi$ bonds. $P_z$ forms $\sigma$ bonds since there is electron density on the bond axis. <br>
# $g$: inversion symmetric
# $u$: inversion asymmetric. For our purposes, $g$ bonding means $u$ antibonding.
#
# Allowable materials: Lecture notes only.
#
# I'll sit right in the front so he doesn't have to worry about me.
#
# Bring a calculator, in general

# %% [markdown]
# - Important formulas for Quiz 1:
#
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# What I'm worried about: quantum numbers (aka degeneracy)
#
# idk

# %% [markdown]
# 1. PEP
# 2. Spread the electrons (due to maximiznig L)
# 3. L and S are parallel, aligned when half-full, unaligned when less than half-full

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Where does this come from? higher momenta are possible with higher quantum numbers. l = n-1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Chapter 2. Condensed Matter
#
# Finally talking about solids

# %% [markdown]
# ## Lattice

# %% [markdown]
# Primitive & Principle vectors

# %% [markdown]
# 2D lattice

# %% [markdown]
# 3D lattice
#
# $\vec a_1, \vec a_2, \vec a_3$ non-coplanar vectors can represent a lattice. $R = (n_1,n_2,n_3)$
#
# Any point on a lattice must be expressible as an integer multiple of Primitive Lattice Vectors (PLVs). In addition, they cannot represent points that aren't on the lattice.

# %% [markdown]
# Primitive unit cell: contians 1 lattice point. Using a lattice and basis any periodic structure can be obtained.
#
# Primitive unit cells can have 4*1/4 lattice point, etc. We like when cells have points in the corners, but they aren't always primitives.
