# %% [markdown]
# # Phy 491 - Hw 4

# %% [markdown]
# Oxygen - the homework assignment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# O: $1s^22s^22p^4$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Spectroscopic notation: $\ ^{2s+1}L_{J} $. Not to be confused with Molecular term symbols $\ ^{2S+1} \Lambda_{g,u}$
#
# $\sum s=1/2 + 1/2 = 1 \rightarrow 2s+1=3$ <br>
# $\sum l=1 \rightarrow S$ - hund's rule #2 <br>
# More than half full: $J = L + S = 2$
#
# Result: $\ ^{3}S_{2}$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Bonding: 10 <br>
# Antibonding: 8 <br>
# Stability: $B = \frac{10-8}{2}=1$ <br>
#
# Since $B>0$, the molecule is stable

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-3.png](attachment:image-3.png)
#
# Great!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Unexcited and excited: $2S+1 = 3 $
#
# Unexcited: $L = 0$ since $-1$ and $1$ are filled <br>
# Excited (unpaired): The antibonding $l_z$ orbital has no momentum on the axis, so $L=1$ <br>
# Excited (paired): $L=2$ since hunt's rules leave both $l_x$ +1 and $l_y$ +1 orbitals open
#
# $g, u$: Not to sure I'll get this one right. I can ask my peers.
#
# Unexcited: $u$ since $\Pi_g*$ is cancelled by $-1$ and $+1$ (PEP) <br>
# Excited (unpaired): $g$
# Excited (paired): none?? idfking know

# %% [markdown]
# ![image.png](attachment:image.png)
