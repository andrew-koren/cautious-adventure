# %% [markdown]
# In this activity, you will work through an example Lagrangian dynamics
# problem. This problem is a standard one which sets up both our
# understanding of the Lagrangian and the Lagrangian equations of motion,
# but also coupled oscillators. The latter is a very important concept in
# physics, and we will see it again in the context of waves. In addition,
# we will change coordinate systems from Cartesian to polar coordinates on
# our way to generalized coordinates.
#
# We should be considering all the conceptual questions asked because
# signs and distances matter in most Lagrangian problems. Setting up the
# problem incorrectly is the most common mistake (we’ve all made it many
# times) because the mathematical process is the same for every problem.
#
# ## Simple Harmonic Oscillator (SHO)
#
# *Note (for this and future problems): the form of the EOM might not look
# the same as the Newtonian approach, but with some algebra we can often
# see that they are equivalent.*
#
# 1.  Starting with the 1D energy equations $T$ and $V$ for
#     a SHO; derive the equations of motion. Use the Lagrangian approach.
#     Did you get the sign right?

# %% [markdown]
# 1D energy of a SHO
#
# Kinetic energy $T = \frac{1}{2}mv^2 = \frac{1}{2}m\dot x^2$
#
# Potential energy of a spring $V=\frac{1}{2}k\left(\Delta x\right)^2= \frac{1}{2}k\left(x-x_0\right)^2 $
#
# $$
# \mathcal{L} = T - V = \frac{1}{2}m\dot x^2-\frac{1}{2}k\left(x-x_0\right)^2  \\
#
# \frac{d}{dt} \frac{\partial L}{\partial \dot x} - \frac{\partial L}{\partial x} = 0
# $$
# Which we need some partials for
#
# $$
# \frac{\partial L}{\partial \dot x} = m \dot x \\
# \frac{d}{dt} \frac{\partial L}{\partial \dot x} = m \ddot x \\
# \frac{\partial L}{\partial x} + k \left(x - x_0\right) = 0 \\
# m\ddot{x} = -k \left(x - x_0\right)
# $$
#
# Not too sure how to do $x_0$

# %% [markdown]
# ## Canonical Coupled Oscillator
#
# <img
# src="https://www.entropy.energy/static/resources/coupled-oscillators/two-coupled-gliders-diagram.png"
# style="max-width: 100%; display: block; margin-left: auto; margin-right: auto;"
# data-d2l-editor-default-img-style="true"
# alt="Coupled Oscillator set up. Two oscillators connected by three springs in a horizontal line." />
#
# 1.  Write down the energy equations for this system
#     (using $x_{1}$ and $x_{2}$ for coordinates)
#
# 2.  Write the Lagrangian for this system.
#
# 3.  Derive the two equations of motion. Why should there be two
#     equations of motion?
#
# 4.  Do all the signs makes sense to you? Why?
#
# 5.  Could you have arrived at these equations in the Newtonian
#     framework? No need to do so, just sketch out how you would have done
#     it.

# %% [markdown]
# Canonial Coupled Oscillator
#
# 1. What's the energy equation for the system?
# Idk, I'll guess
#
# $$
# E = PE_{k1} + PE_{k2} + PE_{k'} + KE_{x1} + KE_{x2}
# $$
#
# 2. The lagrangian
#
# Kinetic energy is a sum of two kinetic energies. I don't want to do anything weird until I hit a dead end, so I'll just go for it
#
# $$
# T = \frac{1}{2}m\dot x_1^2 + \frac{1}{2}m\dot x_2^2 \\
# $$
#
# For potential, let the total length be $L,$ then
#
# $$
# V = \frac{1}{2}kx_1^2 + \frac{1}{2}k\left(x_2 - L \right)^2 + \frac{1}{2}k'(x_2 - x_1)^2
# $$
#
# $$
# \mathcal{L} = T-V = \frac{1}{2}m\dot x_1^2 + \frac{1}{2}m\dot x_2^2 - \frac{1}{2}kx_1^2 - \frac{1}{2}k\left(x_2 - L \right)^2 - \frac{1}{2}k'(x_2 - x_1)^2
# $$
# Unsimplified cuz derivatives
#
# 3. Two equations of motion for two masses
#
# $$
# \frac{d}{dt} \frac{\partial L}{\partial \dot x} - \frac{\partial L}{\partial x} = 0
# $$
#
# $$
# \frac{d}{dt}\frac{\partial L}{\partial \dot x_1} = m\ddot x_1 \\
# \frac{d}{dt}\frac{\partial L}{\partial \dot x_2} = m\ddot x_2 \\
#
# \frac{\partial L}{\partial x_1} = -kx_1 + k'\left(x_2-x_1 \right) \\
# \frac{\partial L}{\partial x_2} = -k(x_2-L) - k'\left(x_2-x_1\right)
# $$
# This gives us the EOMs
#
# $$
# m\ddot x_1 = -kx_1 + k'\left(x_2-x_1 \right) \\
# m\ddot x_2 = -k(x_2-L) - k'\left(x_2-x_1\right)
# $$

# %% [markdown]
# ## Orbital Problem
#
# Consider the two-body orbital problem of a star $M$ and a planet
# $m$ under the force of gravity. Assume the star is stationary.
#
# 1.  Write down the energy equations for this system using polar
#     coordinates. *Note: $v^{2} = {\overset{˙}{r}}^{2} + r^{2}{\overset{˙}{\phi}}^{2}$*
#
# 2.  Write the Lagrangian.
#
# 3.  Derive the $r$ equation of motion. What do you notice about it’s
#     terms? Can you rewrite it in a Netwonian form?
#
# 4.  Derive the $\phi$ equation of motion. What do you notice about it’s
#     time derivative? Does that tell you something about a quantity of
#     the motion (i.e. a conserved quantity)? If so, what is it?

# %% [markdown]
# $$
# KE = \frac{1}{2}m\dot r^2 + \frac{1}{2}mr^2 \dot \phi ^2 \\
# U_G = -\frac{GMm}{r^2}
# $$
#
# $$
# \mathcal{L} = \frac{1}{2}m\dot r^2 + \frac{1}{2}mr^2 \dot \phi ^2 + \frac{GMm}{r^2}
# $$
#
# $$
# \frac{d}{dt} \frac{\partial \mathcal{L}}{\partial \dot r} - \frac{\partial L}{\partial r} = 0 \\
#
# \frac{d}{dt} \frac{\partial \mathcal{L}}{\partial \dot r} = m \ddot r \\
# \frac{d}{dt} \frac{\partial \mathcal{L}}{\partial \dot \phi} = \frac{d}{dt}  mr^2 \dot \phi =  2mr \dot r \dot \phi + m r^2 \ddot \phi  \\
#
# \frac{\partial \mathcal{L}}{\partial r} = mr \dot \phi ^2 -2 \frac{GMm}{r^3}\\
# \frac{\partial \mathcal{L}}{\partial \phi} = 0
# $$
#
# This gives us our EOMs
#
# $$
# \ddot r = r \dot \phi^2 - 2\frac{GM}{r^3} \\
# \ddot \phi = -\frac{2\dot r \dot \phi }{r}
# $$

# %% [markdown]
# ## Constrained motion
#
# The Lagrangian framework also excels at dealing with constrained motion,
# where it is usually not obvious what the constraint forces are. This is
# because you can write your generalized coordinates for your system in
# such a way that it contains the information.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# def parabaloid(x,y,alpha):
#     # function of a paraboloid in Cartesian coordinates
#     return alpha * (x**2 + y**2)
#
# # points of the surface to plot
# x = np.linspace(-2.8, 2.8, 50)
# y = np.linspace(-2.8, 2.8, 50)
# alpha = 1
# # construct meshgrid for plotting
# X, Y = np.meshgrid(x, y)
# Z = parabaloid(X, Y,alpha)
#
# # do plotting
# fig = plt.figure(figsize = (10,10))
# ax = plt.axes(projection='3d')
# plt.title(r"Paraboloid ($\alpha = $" + str(alpha)+ ")")
# ax = plt.axes(projection='3d')
# ax.plot_surface(X, Y, Z, cmap='binary', alpha=0.8)
# ax.set_xlim(-3, 3); ax.set_ylim(-3, 3); ax.set_zlim(-1 ,15)
# ax.set_xlabel('x')
# ax.set_ylabel('y')
# ax.set_zlabel('z')
# plt.show()
# ```
#
# <img
# src="https://dannycaballero.info/phy415fall23/_images/9ba8eb71414a65d0a81c5cccdd8168324484a24b14e7afd86f804f706c20275e.png"
# style="display: block; margin-left: auto; margin-right: auto;"
# width="383" height="392"
# alt="../../../_images/9ba8eb71414a65d0a81c5cccdd8168324484a24b14e7afd86f804f706c20275e.png" />
#
# Consider a particle of mass $m$ constrained to move on the surface of a
# paraboloid $z = c\rho^{2}$ subject to a gravitational force downward, so
# that the paraboloid and gravity are aligned.
#
# 1.  Using cylindrical coordinates, write down the equation of
#     constraint. Think about where the mass must be if it’s stuck on a
#     paraboloid.
#
# 2.  Write the energy contributions in cylindrical coordinates. (This is
#     where you put in the constraint!)
#
# 3.  Form the Lagrangian and find the equations of motion (there are
#     two!)

# %% [markdown]
# ## Roller Coaster on a holonomic track
#
# Consider 3 wagons on a roller coaster cars of equal mass $m$ and
# positions $x_{1},x_{2},x_{3}$, constrained to move on a one dimensional
# “track” defined by $f(x) = x^{4} - 2x^{2} + 1$. These cars are also
# constrained to stay a distance $d$ apart, since they are linked. We’ll
# only worry about that distance $d$ in $x$ direction for now.
#
# ```python
# x = np.arange(-1.8,1.8,0.01)
# track = lambda x : x**4 - 2*x**2 + 1
# y = track(x)
# d = 0.1
# x1_0 = -1.5
# x2_0 = x1_0 - d
# x3_0 = x1_0 - 2*d
# plt.plot(x,y, label = "track")
# plt.scatter(x1_0,track(x1_0),zorder = 2,label = r"$x_1$")
# plt.scatter(x2_0,track(x2_0),zorder = 2,label = r"$x_2$")
# plt.scatter(x3_0,track(x3_0),zorder = 2,label = r"$x_3$")
# plt.legend()
# plt.grid()
# plt.show()
# ```
#
# <img
# src="https://dannycaballero.info/phy415fall23/_images/ad05f9e72758d78584b58ac673d953b77835e367faae9de7241e153c303c1c20.png"
# style="display: block; margin-left: auto; margin-right: auto;"
# width="290" height="224"
# alt="../../../_images/ad05f9e72758d78584b58ac673d953b77835e367faae9de7241e153c303c1c20.png" />
#
# 1.  Write down the equation(s) of constraint. How many coordinates do
#     you actually need?
#
# 2.  Write the energies of the system using your generalized coordinates.
#
# 3.  Form the Lagrangian and find the equation(s?) of motion (how many
#     are there?)
#
# 4.  Are the dynamics of this system different that the dynamics of a
#     system of just one roller coaster car?

# %% [markdown]
# $$
# x_1 = x_2 + d \\
# x_2 = x_3 + d \\
# x_1 = x_3 + 2d
# $$
# From this relation, we can reduce the problem.
# $$
# T = \frac{1}{2}m \left(\dot x_2^2 + \dot x_2^2 + \dot x_2^2  \right) \\ = \frac{3}{2} \dot x_2^2 \\
# $$
#
# For the roller coaster, use $V = mg(y_1+y_2+y_3)$ with the coaster track function $y = x^4 - 2x^2+1$
#
# $$
# V = mg(y_1+y_2+y_3) \\= mg\left( (x_2+d)^4 - 2(x_2+d)^2+x_2^4-2x_2^2+(x_2-d)^4 - 2(x_2-d)^2+3\right)
# $$

# %% [markdown]
# Braiden Vasily Nate
