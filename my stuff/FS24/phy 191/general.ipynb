# %% [markdown]
# a Assuming the arbitrary mass has a spring attached to it
#
# ![image.png](attachment:image.png)

# %% [markdown]
# b $F_{net} = F_s + F_g$
#
# Using $g=9.81$
# $$
# m a = k x - m g \\
# a = \frac{kx}{m}-g
# $$
#
# c No acceleration $a = 0$
#
# $$
# x\frac{k}{m} = g\\
# x = g\frac{m}{k}
# $$
#
# d
#
# $$
# 9.8\frac{1}{7} = 1.4
# $$
#
# e see plot below. The slope is linear
#
# f This plot would be the same plus some offset between the top and bottom, ie $x+c= g\frac{m}{k}$
#
# g The direction of the force (pos, neg, up, down, etc) depends on the coordinate system used, although the magnitude is independent.

# %%
# d
k = 7
g = 9.8
print(g/k)

# e
import matplotlib.pyplot as plt
from numpy import array
def x(m, g=g, k=k):
    return g*m/k

m = array([2, 4, 6])
plt.plot(m, x(m), marker='o')
plt.title(f'displacement vs mass k={k}kg/m')
plt.xlabel('mass (kg)')
plt.ylabel('displacement (m)')
# Out:
# 1.4000000000000001
# Text(0, 0.5, 'displacement (m)')

# %% [markdown]
# 2 Based on this observation, Hooke's law fails for large enough displacement such that the spring is deformed
#
# 3 Gravity is not necessary, since the restorative force above and below equilibrium posistion is what causes oscillation. Gravity just shifts the equilibrium length.
