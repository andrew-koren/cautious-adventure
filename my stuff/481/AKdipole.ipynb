# %% [markdown]
# # Homework 10.5: Python: Dipole Animation
#
# The purpose of this problem is study the Electric Field due to a dipole at different distances from the dipole as the separation between the two charges changes. As a reminder, the electric field due to a point charge is:
#
# $$\vec{E} = k q \left [ \frac{\vec{r}_\mathrm{observation} - \vec{r}_\mathrm{source}}{\left |  \vec{r}_\mathrm{observation} - \vec{r}_\mathrm{source}\right |^3} \right ] $$
#
# This excercise will also provide you with an opportunity to learn how to make an animated gif. The generation of the animation make take some time (a few minutes) depending on your computer so please be patient. The output is an animated gif file named "temp.gif" - this file can be openned in a web browser for viewing. If your computer is fast enough, then you can see the animation in real time within the notebook. Otherwise, viewing the animated gif file in a web browswer may be the better option.

# %%
# will need this to determine how long it takes to generate the animation
from datetime import datetime

# importing numpy and matplotlib array manipulation and plotting/animation libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

#enable interactive plot in the notebook
#%matplotlib notebook

# Create new Figure with the appropriate size
fig = plt.figure(figsize = (12,4))

# this is the function that is called to generate each frame of the animation
# there are two parts - first the locations of the charges are displayed as red (positive) and blue (negative dots)
# second the electric field lines are calculated and plotted as "stream lines"
# 
# frame_number is the variable that is being updated within each frame
# in this case, it is related to the location of the charges
#
def update(frame_number):
    
    # location of the positive charge (r_source vector for + charge)
    xp = 0.0
    yp = +2.0*(1.05-np.sin(frame_number))

    # location of the negative charge (r_source vector for - charge)
    xm = 0.0
    ym = -2.0*(1.05-np.sin(frame_number))
        
    # clearing out the previous plot and setting the axes limits    
    plt.clf()
    plt.axes(xlim = (-12.0,+12.0), ylim = (-4.0,+4.0))
    
    # plotting the location of the positive (red) and negative (blue) charges
    plt.plot(xp,yp,'ro',scalex = False, scaley = False)
    plt.plot(xm,ym,'bo',scalex = False, scaley = False)
    
    # creating a 2D mesh of points where the electric fields should be calculated  (r_observation vectors)
    xarray = np.linspace(-12.0,+12.0,100)
    yarray = np.linspace(-4.0,+4.0,100)
    X,Y = np.meshgrid(xarray,yarray)
    
    # defining the constants needed for calculating the electric fields
    # note that the magnitude of the charge changes as the distance between the charges changes
    # this is to keep the electric dipole moment of this system constant
    k = 9.0E9
    q = 1.0E-6*(4.0/np.abs(yp-ym))

    # in order to plot the electric field stream lines, we need to calculate the two components of the electric field separately
    # you will need to fill this part in - remember the definition of Griffiths script-r: (observation point) - (source location)
    # Epx = x-component of the electric field due to the positive charge
    # Epy = y-component of the electric field due to the positive charge
    Epx = X
    Epy = Y

    # Emx = x-component of the electric field due to the negative charge
    # Emy = y-component of the electric field due to the negative charge
    Emx = X
    Emy = Y

    # Ex = x-component of the total electric field
    # Ey = y-component of the total electric field
    Ex = X
    Ey = Y
    
    # setting the color of the arrows in the streamline plot to be scaled to the electric field magnitude
    arrowcolor = np.log(Ex**2 + Ey**2)

    # plotting the electric field lines
    plt.streamplot(X,Y,Ex,Ey,linewidth = 1,color = arrowcolor, arrowstyle = '->' , density = 2.0, arrowsize = 2.0)
    
# setting the number of frames in the animation 
maxframes = 100

# getting the current time in order to calculate the total animation generation duration
t1 = datetime.now()

# creates the animation, each frame corresponds to a different charge separation
ani = FuncAnimation(fig, update, frames = np.linspace(0,np.pi,maxframes), interval=10)
plt.show()

# saves the animation as an animated gif
ani.save("temp.gif")

# getting the current time after the animation generation
t2 = datetime.now()

# letting you know that the animation is done and the time it took to generate it
print("done: ",t2-t1)
# Out:
# <div id='2b7c4be8-40e1-4cf5-a09e-73176d07c9dd'></div>
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\andre\the actual coding folder\cautious-adventure\my stuff\481\HW07_Electric_dipole_animation.ipynb Cell 2 line 8
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/the%20actual%20coding%20folder/cautious-adventure/my%20stuff/481/HW07_Electric_dipole_animation.ipynb#W1sZmlsZQ%3D%3D?line=81'>82</a> plt.show()
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/the%20actual%20coding%20folder/cautious-adventure/my%20stuff/481/HW07_Electric_dipole_animation.ipynb#W1sZmlsZQ%3D%3D?line=83'>84</a> # saves the animation as an animated gif
# ---> <a href='vscode-notebook-cell:/c%3A/Users/andre/the%20actual%20coding%20folder/cautious-adventure/my%20stuff/481/HW07_Electric_dipole_animation.ipynb#W1sZmlsZQ%3D%3D?line=84'>85</a> ani.save("temp.gif")
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/the%20actual%20coding%20folder/cautious-adventure/my%20stuff/481/HW07_Electric_dipole_animation.ipynb#W1sZmlsZQ%3D%3D?line=86'>87</a> # getting the current time after the animation generation
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/the%20actual%20coding%20folder/cautious-adventure/my%20stuff/481/HW07_Electric_dipole_animation.ipynb#W1sZmlsZQ%3D%3D?line=87'>88</a> t2 = datetime.now()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:1103, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1100 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1101     for anim, d in zip(all_anim, data):
#    1102         # TODO: See if turning off blit is really necessary
# -> 1103         anim._draw_next_frame(d, blit=False)
#    1104         if progress_callback is not None:
#    1105             progress_callback(frame_number, total_frames)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:1138, in Animation._draw_next_frame(self, framedata, blit)
#    1134 def _draw_next_frame(self, framedata, blit):
#    1135     # Breaks down the drawing of the next frame into steps of pre- and
#    1136     # post- draw, as well as the drawing of the frame itself.
#    1137     self._pre_draw(framedata, blit)
# -> 1138     self._draw_frame(framedata)
#    1139     self._post_draw(framedata, blit)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:1767, in FuncAnimation._draw_frame(self, framedata)
#    1763     self._save_seq = self._save_seq[-self._save_count:]
#    1765 # Call the func with framedata and args. If blitting is desired,
#    1766 # func needs to return a sequence of any artists that were modified.
# -> 1767 self._drawn_artists = self._func(framedata, *self._args)
#    1769 if self._blit:
#    1771     err = RuntimeError('The animation function must return a sequence '
#    1772                        'of Artist objects.')
#
# c:\Users\andre\the actual coding folder\cautious-adventure\my stuff\481\HW07_Electric_dipole_animation.ipynb Cell 2 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/the%20actual%20coding%20folder/cautious-adventure/my%20stuff/481/HW07_Electric_dipole_animation.ipynb#W1sZmlsZQ%3D%3D?line=68'>69</a> arrowcolor = np.log(Ex**2 + Ey**2)
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/the%20actual%20coding%20folder/cautious-adventure/my%20stuff/481/HW07_Electric_dipole_animation.ipynb#W1sZmlsZQ%3D%3D?line=70'>71</a> # plotting the electric field lines
# ---> <a href='vscode-notebook-cell:/c%3A/Users/andre/the%20actual%20coding%20folder/cautious-adventure/my%20stuff/481/HW07_Electric_dipole_animation.ipynb#W1sZmlsZQ%3D%3D?line=71'>72</a> plt.streamplot(X,Y,Ex,Ey,linewidth = 1,color = arrowcolor, arrowstyle = '->' , density = 2.0, arrowsize = 2.0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\pyplot.py:2953, in streamplot(x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, start_points, maxlength, integration_direction, broken_streamlines, data)
#    2946 @_copy_docstring_and_deprecators(Axes.streamplot)
#    2947 def streamplot(
#    2948         x, y, u, v, density=1, linewidth=None, color=None, cmap=None,
#    (...)
#    2951         integration_direction='both', broken_streamlines=True, *,
#    2952         data=None):
# -> 2953     __ret = gca().streamplot(
#    2954         x, y, u, v, density=density, linewidth=linewidth, color=color,
#    2955         cmap=cmap, norm=norm, arrowsize=arrowsize,
#    2956         arrowstyle=arrowstyle, minlength=minlength,
#    2957         transform=transform, zorder=zorder, start_points=start_points,
#    2958         maxlength=maxlength,
#    2959         integration_direction=integration_direction,
#    2960         broken_streamlines=broken_streamlines,
#    2961         **({"data": data} if data is not None else {}))
#    2962     sci(__ret.lines)
#    2963     return __ret
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\__init__.py:1459, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1456 @functools.wraps(func)
#    1457 def inner(ax, *args, data=None, **kwargs):
#    1458     if data is None:
# -> 1459         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1461     bound = new_sig.bind(ax, *args, **kwargs)
#    1462     auto_label = (bound.arguments.get(label_namer)
#    1463                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\streamplot.py:155, in streamplot(axes, x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, start_points, maxlength, integration_direction, broken_streamlines)
#     153 if mask[ym, xm] == 0:
#     154     xg, yg = dmap.mask2grid(xm, ym)
# --> 155     t = integrate(xg, yg, broken_streamlines)
#     156     if t is not None:
#     157         trajectories.append(t)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\streamplot.py:484, in _get_integrator.<locals>.integrate(x0, y0, broken_streamlines)
#     482     return None
#     483 if integration_direction in ['both', 'backward']:
# --> 484     s, xyt = _integrate_rk12(x0, y0, dmap, backward_time, maxlength,
#     485                              broken_streamlines)
#     486     stotal += s
#     487     xy_traj += xyt[::-1]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\streamplot.py:561, in _integrate_rk12(x0, y0, dmap, f, maxlength, broken_streamlines)
#     556         raise OutOfBounds
#     558     # Compute the two intermediate gradients.
#     559     # f should raise OutOfBounds if the locations given are
#     560     # outside the grid.
# --> 561     k1x, k1y = f(xi, yi)
#     562     k2x, k2y = f(xi + ds * k1x, yi + ds * k1y)
#     564 except OutOfBounds:
#     565     # Out of the domain during this step.
#     566     # Take an Euler step to the boundary to improve neatness
#     567     # unless the trajectory is currently empty.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\streamplot.py:462, in _get_integrator.<locals>.backward_time(xi, yi)
#     461 def backward_time(xi, yi):
# --> 462     dxi, dyi = forward_time(xi, yi)
#     463     return -dxi, -dyi
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\streamplot.py:453, in _get_integrator.<locals>.forward_time(xi, yi)
#     451 if not dmap.grid.within_grid(xi, yi):
#     452     raise OutOfBounds
# --> 453 ds_dt = interpgrid(speed, xi, yi)
#     454 if ds_dt == 0:
#     455     raise TerminateTrajectory()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\streamplot.py:654, in interpgrid(a, xi, yi)
#     651         yn = y + 1
#     653 a00 = a[y, x]
# --> 654 a01 = a[y, xn]
#     655 a10 = a[yn, x]
#     656 a11 = a[yn, xn]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\ma\core.py:3255, in MaskedArray.__getitem__(self, indx)
#    3251 if _mask is not nomask:
#    3252     # _mask cannot be a subclass, so it tells us whether we should
#    3253     # expect a scalar. It also cannot be of dtype object.
#    3254     mout = _mask[indx]
# -> 3255     scalar_expected = _is_scalar(mout)
#    3257 else:
#    3258     # attempt to apply the heuristic to avoid constructing a full mask
#    3259     mout = nomask
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\ma\core.py:3225, in MaskedArray.__getitem__.<locals>._is_scalar(m)
#    3222 dout = self.data[indx]
#    3223 _mask = self._mask
# -> 3225 def _is_scalar(m):
#    3226     return not isinstance(m, np.ndarray)
#    3228 def _scalar_heuristic(arr, elem):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Problems to Solve
# **Calculate the Electric Fields:**  Put in the correct formulas into the code above for the x and y components of the electric field due to the positive charge (Epx and Epy) and the negative charge (Emx and Emy) as well as for the total electric field (Ex and Ey). In the template file, all are set to X and Y as placeholders.
#
# Upload on D2L both the Jupyter notebook file and the animated gif file.

# %%
# will need this to determine how long it takes to generate the animation
from datetime import datetime

# importing numpy and matplotlib array manipulation and plotting/animation libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

#enable interactive plot in the notebook
# %matplotlib notebook

# Create new Figure with the appropriate size
fig = plt.figure(figsize = (12,4))

# this is the function that is called to generate each frame of the animation
# there are two parts - first the locations of the charges are displayed as red (positive) and blue (negative dots)
# second the electric field lines are calculated and plotted as "stream lines"
# 
# frame_number is the variable that is being updated within each frame
# in this case, it is related to the location of the charges
#
def update(frame_number):
    
    # location of the positive charge (r_source vector for + charge)
    xp = 0.0
    yp = +2.0*(1.05-np.sin(frame_number))
    
    # location of the negative charge (r_source vector for - charge)
    xm = 0.0
    ym = -2.0*(1.05-np.sin(frame_number))
        
    # clearing out the previous plot and setting the axes limits    
    plt.clf()
    plt.axes(xlim = (-12.0,+12.0), ylim = (-4.0,+4.0))
    
    # plotting the location of the positive (red) and negative (blue) charges
    plt.plot(xp,yp,'ro',scalex = False, scaley = False)
    plt.plot(xm,ym,'bo',scalex = False, scaley = False)
    
    # creating a 2D mesh of points where the electric fields should be calculated  (r_observation vectors)
    xarray = np.linspace(-12.0,+12.0,100)
    yarray = np.linspace(-4.0,+4.0,100)
    X,Y = np.meshgrid(xarray,yarray)
    
    # defining the constants needed for calculating the electric fields
    # note that the magnitude of the charge changes as the distance between the charges changes
    # this is to keep the electric dipole moment of this system constant
    k = 9.0E9
    q = 1.0E-6*(4.0/np.abs(yp-ym))


    ###### Important stuff starts here ######

    # in order to plot the electric field stream lines, we need to calculate the two components of the electric field separately
    # you will need to fill this part in - remember the definition of Griffiths script-r: (observation point) - (source location)
    # Epx = x-component of the electric field due to the positive charge
    # Epy = y-component of the electric field due to the positive charge
    qp_location = np.array([xp, yp])
    
    r = np.array([X, Y])
    r0p = qp_location[:, np.newaxis, np.newaxis]
    r_minus_r0p = r - r0p
    r_normp = np.linalg.norm(r_minus_r0p, axis=0)
    r_norm_cubedp = r_normp**3

    Exp = k * q * (r_minus_r0p[0] / r_norm_cubedp)
    Eyp = k * q * (r_minus_r0p[1] / r_norm_cubedp)

    # Emx = x-component of the electric field due to the negative charge
    # Emy = y-component of the electric field due to the negative charge
    qm_location = np.array([xm, ym])
    
    r0m = qm_location[:, np.newaxis, np.newaxis]
    r_minus_r0m = r - r0m
    r_normm = np.linalg.norm(r_minus_r0m, axis=0)
    r_norm_cubedm = r_normm**3

    Exm = k * q * (r_minus_r0m[0] / r_norm_cubedm)
    Eym = k * q * (r_minus_r0m[1] / r_norm_cubedm)

    # Ex = x-component of the total electric field
    # Ey = y-component of the total electric field
    Ex = Exp - Exm
    Ey = Eyp - Eym
    
    # setting the color of the arrows in the streamline plot to be scaled to the electric field magnitude
    #professor being fancy#
    arrowcolor = np.log(Ex**2 + Ey**2)

    # plotting the electric field lines
    #Streamplot reads location (x,y) and plots towards the next point (x+Ex,y+Ey)#
    plt.streamplot(X,Y,Ex,Ey,linewidth = 1,color = arrowcolor, arrowstyle = '->' , density = 2.0, arrowsize = 2.0)
    
#All the stuff after here is just plotting stuff#
#xp,yp,X,Y = update(0)
#X[0]

# setting the number of frames in the animation 
maxframes = 100

# getting the current time in order to calculate the total animation generation duration
t1 = datetime.now()

# creates the animation, each frame corresponds to a different charge separation
ani = FuncAnimation(fig, update, frames = np.linspace(0,np.pi,maxframes), interval=30)
plt.show()

# saves the animation as an animated gif
ani.save("efield.gif")

# getting the current time after the animation generation
t2 = datetime.now()

# letting you know that the animation is done and the time it took to generate it
print("done: ",t2-t1)
# Out:
# <div id='0c86629c-bac4-4965-96cb-b21d36571215'></div>
# MovieWriter ffmpeg unavailable; using Pillow instead.
# done:  0:01:48.392194
